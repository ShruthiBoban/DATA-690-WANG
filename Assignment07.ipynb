# %% [markdown]
# ## Assignment 07
# You can use the local Jupyter environment if you are not comfortable with Colab for this assignment.
#
# The first half of this assignment is a repeat of assignment 05.
#
# This gives you a chance to refresh.
#
# The second half is new and gives you a chance to perform additional practices.
#
# You also get a chance to use some of the Python libraries and techniques.
#
# You will unzip the zip file manually in preparation for this assignment.
#
# The link to the zip file is (you have already used it in your assignment 5):
#
# https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data.zip
#
# After unzipping, You will have all files in one folder named "CollegeScorecard_Raw_Data"
#
# The folder contains the yearly data files from 1996 to 2019 school years.
#
# if you are using your local environment, I suggest you create a new folder call "Assignment7" and place the Notebook file and the data folder under it.
#
# Assignment7/
#     - assignment_07.ipynb
#     - CollegeScorecard_Raw_Data/
#         - ...
#         - 'MERGED1996_97_PP.csv',
#         - 'MERGED2015_16_PP.csv',
#         - ...
#         - 'MERGED2017_18_PP.csv'

# %% [markdown]
# 1. Import libraries

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure 
import numpy as np

# %% [markdown]
# 2. Display the current workin directory

# %%
os.getcwd()
# Out:
# 'C:\\Users\\shrut\\Assignment07'

# %% [markdown]
# 3. Generate a list of files in a directory/folder

# %%
#https://thispointer.com/python-how-to-get-list-of-files-in-directory-and-sub-directories/
def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
                
    return allFiles
dirName = 'C:\\Users\\shrut\\Assignment07\CollegeScorecard_Raw_Data';
# Get the list of all files in directory tree at given path
listOfFiles = getListOfFiles(dirName)

# %%
listOfFiles
# Out:
# ['C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\a.DS_Store',
#  'C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\Crosswalks.zip',
#  'C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\data.yaml',
#  'C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\FieldOfStudyData1415_1516_PP.csv',
#  'C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\FieldOfStudyData1516_1617_PP.csv',
#  'C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED1996_97_PP.csv',
#  'C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED1997_98_PP.csv',
#  'C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED1998_99_PP.csv',
#  'C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED1999_00_PP.csv',
#  'C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2000_01_PP.csv',
#  'C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2001_02_PP.csv',
# ...

# %% [markdown]
# 4. Remove unwanted files and keep the files that have "merged" mentioned in them

# %%
os.remove('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\data.yaml')

# %%
os.remove('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\Crosswalks.zip')

# %%
os.remove('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\a.DS_Store')

# %%
os.remove('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\FieldOfStudyData1415_1516_PP.csv')

# %%
os.remove('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\FieldOfStudyData1516_1617_PP.csv')

# %%
listOfFilesFinal = getListOfFiles(dirName)

# %%
listOfFilesFinal
# Out:
# ['C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED1996_97_PP.csv',
#  'C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED1997_98_PP.csv',
#  'C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED1998_99_PP.csv',
#  'C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED1999_00_PP.csv',
#  'C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2000_01_PP.csv',
#  'C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2001_02_PP.csv',
#  'C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2002_03_PP.csv',
#  'C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2003_04_PP.csv',
#  'C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2004_05_PP.csv',
#  'C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2005_06_PP.csv',
#  'C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2006_07_PP.csv',
# ...

# %% [markdown]
# 5. Create dataframes one at a time for the yearly files while having a new column "Year" in the dataframes

# %%
df1 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED1996_97_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df1['Year'] = '1996'
df1.head()
# Out:
#    UNITID                                  INSTNM STABBR  REGION  ADM_RATE  \
# 0  100636      Community College of the Air Force     AL       0       NaN
# 1  100654                Alabama A & M University     AL       5       NaN
# 2  100663     University of Alabama at Birmingham     AL       5       NaN
# 3  100672  ALABAMA AVIATION AND TECHNICAL COLLEGE     AL       5       NaN
# 4  100690                      Amridge University     AL       5       NaN
#
#    TUITIONFEE_IN  Year
# 0            NaN  1996
# 1            NaN  1996
# 2            NaN  1996
# 3            NaN  1996
# 4            NaN  1996

# %%
df2 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED1997_98_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df2['Year'] = '1997'
df2.head()
# Out:
#    UNITID                                  INSTNM STABBR  REGION  ADM_RATE  \
# 0  100636      Community College of the Air Force     AL       0       NaN
# 1  100654                Alabama A & M University     AL       5       NaN
# 2  100663     University of Alabama at Birmingham     AL       5       NaN
# 3  100672  ALABAMA AVIATION AND TECHNICAL COLLEGE     AL       5       NaN
# 4  100690                      Amridge University     AL       5       NaN
#
#    TUITIONFEE_IN  Year
# 0            NaN  1997
# 1            NaN  1997
# 2            NaN  1997
# 3            NaN  1997
# 4            NaN  1997

# %%
df3 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED1998_99_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df3['Year'] = '1998'
df3.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100654             Alabama A & M University     AL       5       NaN
# 1  100663  University of Alabama at Birmingham     AL       5       NaN
# 2  100690                   Amridge University     AL       5       NaN
# 3  100706  University of Alabama in Huntsville     AL       5       NaN
# 4  100724             Alabama State University     AL       5       NaN
#
#    TUITIONFEE_IN  Year
# 0            NaN  1998
# 1            NaN  1998
# 2            NaN  1998
# 3            NaN  1998
# 4            NaN  1998

# %%
df4 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED1999_00_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df4['Year'] = '1999'
df4.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100654             Alabama A & M University     AL       5       NaN
# 1  100663  University of Alabama at Birmingham     AL       5       NaN
# 2  100690                   Amridge University     AL       5       NaN
# 3  100706  University of Alabama in Huntsville     AL       5       NaN
# 4  100724             Alabama State University     AL       5       NaN
#
#    TUITIONFEE_IN  Year
# 0            NaN  1999
# 1            NaN  1999
# 2            NaN  1999
# 3            NaN  1999
# 4            NaN  1999

# %%
df5 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2000_01_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df5['Year'] = '2000'
df5.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100636   Community College of the Air Force     AL       0       NaN
# 1  100654             Alabama A & M University     AL       5       NaN
# 2  100663  University of Alabama at Birmingham     AL       5       NaN
# 3  100690                   Amridge University     AL       5       NaN
# 4  100706  University of Alabama in Huntsville     AL       5       NaN
#
#    TUITIONFEE_IN  Year
# 0            NaN  2000
# 1         4664.0  2000
# 2         3363.0  2000
# 3            NaN  2000
# 4         3112.0  2000

# %%
df6 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2001_02_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df6['Year'] = '2001'
df6.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100636   Community College of the Air Force     AL       0       NaN
# 1  100654             Alabama A & M University     AL       5    0.7505
# 2  100663  University of Alabama at Birmingham     AL       5    0.9098
# 3  100690                   Amridge University     AL       5       NaN
# 4  100706  University of Alabama in Huntsville     AL       5    0.8381
#
#    TUITIONFEE_IN  Year
# 0            NaN  2001
# 1         4664.0  2001
# 2         3640.0  2001
# 3            NaN  2001
# 4         3536.0  2001

# %%
df10 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2002_03_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df10['Year'] = '2002'
df10.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100636   Community College of the Air Force     AL       0       NaN
# 1  100654             Alabama A & M University     AL       5    0.5575
# 2  100663  University of Alabama at Birmingham     AL       5    0.9117
# 3  100690                   Amridge University     AL       5       NaN
# 4  100706  University of Alabama in Huntsville     AL       5    0.9050
#
#    TUITIONFEE_IN  Year
# 0            NaN  2002
# 1         3040.0  2002
# 2         3880.0  2002
# 3         8960.0  2002
# 4         3764.0  2002

# %%
df11 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2003_04_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df11['Year'] = '2003'
df11.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100636   Community College of the Air Force     AL       0       NaN
# 1  100654             Alabama A & M University     AL       5    0.4457
# 2  100663  University of Alabama at Birmingham     AL       5    0.8049
# 3  100690                   Amridge University     AL       5       NaN
# 4  100706  University of Alabama in Huntsville     AL       5    0.8756
#
#    TUITIONFEE_IN  Year
# 0            NaN  2003
# 1         3352.0  2003
# 2         4274.0  2003
# 3         9440.0  2003
# 4         4126.0  2003

# %%
df12 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2004_05_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df12['Year'] = '2004'
df12.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100636   Community College of the Air Force     AL       0       NaN
# 1  100654             Alabama A & M University     AL       5    0.4751
# 2  100663  University of Alabama at Birmingham     AL       5    0.8592
# 3  100690                   Amridge University     AL       5       NaN
# 4  100706  University of Alabama in Huntsville     AL       5    0.8944
#
#    TUITIONFEE_IN  Year
# 0            NaN  2004
# 1         4420.0  2004
# 2         4662.0  2004
# 3        10040.0  2004
# 4         4516.0  2004

# %%
df13 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2005_06_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df13['Year'] = '2005'
df13.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100636   Community College of the Air Force     AL       0       NaN
# 1  100654             Alabama A & M University     AL       5    0.4199
# 2  100663  University of Alabama at Birmingham     AL       5    0.8769
# 3  100690                   Amridge University     AL       5       NaN
# 4  100706  University of Alabama in Huntsville     AL       5    0.8716
#
#    TUITIONFEE_IN  Year
# 0            NaN  2005
# 1         4420.0  2005
# 2         4792.0  2005
# 3        10400.0  2005
# 4         4688.0  2005

# %%
df14 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2006_07_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df14['Year'] = '2006'
df14.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100636   Community College of the Air Force     AL       0       NaN
# 1  100654             Alabama A & M University     AL       5    0.4118
# 2  100663  University of Alabama at Birmingham     AL       5    0.8778
# 3  100690                   Amridge University     AL       5       NaN
# 4  100706  University of Alabama in Huntsville     AL       5    0.8834
#
#    TUITIONFEE_IN  Year
# 0            NaN  2006
# 1         3640.0  2006
# 2         4792.0  2006
# 3         6000.0  2006
# 4         4848.0  2006

# %%
df15 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2007_08_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df15['Year'] = '2007'
df15.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100636   Community College of the Air Force     AL       0       NaN
# 1  100654             Alabama A & M University     AL       5    0.3182
# 2  100663  University of Alabama at Birmingham     AL       5    0.8778
# 3  100690                   Amridge University     AL       5       NaN
# 4  100706  University of Alabama in Huntsville     AL       5    0.8800
#
#    TUITIONFEE_IN  Year
# 0            NaN  2007
# 1         4072.0  2007
# 2         4208.0  2007
# 3         6240.0  2007
# 4         5216.0  2007

# %%
df16 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2008_09_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df16['Year'] = '2008'
df16.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100636   Community College of the Air Force     AL       0       NaN
# 1  100654             Alabama A & M University     AL       5    0.4900
# 2  100663  University of Alabama at Birmingham     AL       5    0.8510
# 3  100690                   Amridge University     AL       5       NaN
# 4  100706  University of Alabama in Huntsville     AL       5    0.8917
#
#    TUITIONFEE_IN  Year
# 0            NaN  2008
# 1         4072.0  2008
# 2         4664.0  2008
# 3         6600.0  2008
# 4         5952.0  2008

# %%
df17 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2009_10_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df17['Year'] = '2009'
df17.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100636   Community College of the Air Force     AL       0       NaN
# 1  100654             Alabama A & M University     AL       5    0.4726
# 2  100663  University of Alabama at Birmingham     AL       5    0.8357
# 3  100690                   Amridge University     AL       5    0.8750
# 4  100706  University of Alabama in Huntsville     AL       5    0.7209
#
#    TUITIONFEE_IN  Year
# 0            NaN  2009
# 1         4692.0  2009
# 2         5096.0  2009
# 3         8000.0  2009
# 4         6510.0  2009

# %%
df18 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2010_11_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df18['Year'] = '2010'
df18.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100636   Community College of the Air Force     AL       0       NaN
# 1  100654             Alabama A & M University     AL       5    0.5129
# 2  100663  University of Alabama at Birmingham     AL       5    0.8243
# 3  100690                   Amridge University     AL       5    0.7143
# 4  100706  University of Alabama in Huntsville     AL       5    0.6614
#
#    TUITIONFEE_IN  Year
# 0            NaN  2010
# 1         5800.0  2010
# 2         5806.0  2010
# 3         8360.0  2010
# 4         7492.0  2010

# %%
df19 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2011_12_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df19['Year'] = '2011'
df19.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100654             Alabama A & M University     AL     5.0    0.5010
# 1  100663  University of Alabama at Birmingham     AL     5.0    0.7223
# 2  100690                   Amridge University     AL     5.0       NaN
# 3  100706  University of Alabama in Huntsville     AL     5.0    0.6368
# 4  100724             Alabama State University     AL     5.0    0.5080
#
#    TUITIONFEE_IN  Year
# 0         6828.0  2011
# 1         6264.0  2011
# 2         8720.0  2011
# 3         8094.0  2011
# 4         8082.0  2011

# %%
df20 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2012_13_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df20['Year'] = '2012'
df20.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100636   Community College of the Air Force     AL       0       NaN
# 1  100654             Alabama A & M University     AL       5    0.5438
# 2  100663  University of Alabama at Birmingham     AL       5    0.7223
# 3  100690                   Amridge University     AL       5       NaN
# 4  100706  University of Alabama in Huntsville     AL       5    0.7766
#
#    TUITIONFEE_IN  Year
# 0            NaN  2012
# 1         7182.0  2012
# 2         6798.0  2012
# 3         6800.0  2012
# 4         8794.0  2012

# %%
df21 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2013_14_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df21['Year'] = '2013'
df21.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100654             Alabama A & M University     AL       5    0.8989
# 1  100663  University of Alabama at Birmingham     AL       5    0.8673
# 2  100690                   Amridge University     AL       5       NaN
# 3  100706  University of Alabama in Huntsville     AL       5    0.8062
# 4  100724             Alabama State University     AL       5    0.5125
#
#    TUITIONFEE_IN  Year
# 0         7182.0  2013
# 1         7206.0  2013
# 2         6870.0  2013
# 3         9192.0  2013
# 4         8720.0  2013

# %%
df22 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2014_15_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df22['Year'] = '2014'
df22.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100654             Alabama A & M University     AL       5    0.5256
# 1  100663  University of Alabama at Birmingham     AL       5    0.8569
# 2  100690                   Amridge University     AL       5       NaN
# 3  100706  University of Alabama in Huntsville     AL       5    0.8203
# 4  100724             Alabama State University     AL       5    0.5326
#
#    TUITIONFEE_IN  Year
# 0         9096.0  2014
# 1         7510.0  2014
# 2         6900.0  2014
# 3         9158.0  2014
# 4         8720.0  2014

# %%
df23 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2015_16_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df23['Year'] = '2015'
df23.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100654             Alabama A & M University     AL       5    0.6538
# 1  100663  University of Alabama at Birmingham     AL       5    0.6043
# 2  100690                   Amridge University     AL       5       NaN
# 3  100706  University of Alabama in Huntsville     AL       5    0.8120
# 4  100724             Alabama State University     AL       5    0.4639
#
#    TUITIONFEE_IN  Year
# 0         9366.0  2015
# 1         7766.0  2015
# 2         6900.0  2015
# 3         9128.0  2015
# 4         8720.0  2015

# %%
df24 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2016_17_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df24['Year'] = '2016'
df24.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100654             Alabama A & M University     AL       5    0.8738
# 1  100663  University of Alabama at Birmingham     AL       5    0.5814
# 2  100690                   Amridge University     AL       5       NaN
# 3  100706  University of Alabama in Huntsville     AL       5    0.7628
# 4  100724             Alabama State University     AL       5    0.4590
#
#    TUITIONFEE_IN  Year
# 0         9366.0  2016
# 1         8040.0  2016
# 2         7180.0  2016
# 3         9842.0  2016
# 4         9220.0  2016

# %%
df25 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2017_18_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df25['Year'] = '2017'
df25.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100654             Alabama A & M University     AL       5    0.9027
# 1  100663  University of Alabama at Birmingham     AL       5    0.9181
# 2  100690                   Amridge University     AL       5       NaN
# 3  100706  University of Alabama in Huntsville     AL       5    0.8123
# 4  100724             Alabama State University     AL       5    0.9787
#
#    TUITIONFEE_IN  Year
# 0         9857.0  2017
# 1         8328.0  2017
# 2         6900.0  2017
# 3        10280.0  2017
# 4        11068.0  2017

# %%
df26 = pd.read_csv('C:\\Users\\shrut\\Assignment07\\CollegeScorecard_Raw_Data\\MERGED2018_19_PP.csv', usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])

df26['Year'] = '2018'
df26.head()
# Out:
#    UNITID                               INSTNM STABBR  REGION  ADM_RATE  \
# 0  100654             Alabama A & M University     AL       5    0.8986
# 1  100663  University of Alabama at Birmingham     AL       5    0.9211
# 2  100690                   Amridge University     AL       5       NaN
# 3  100706  University of Alabama in Huntsville     AL       5    0.8087
# 4  100724             Alabama State University     AL       5    0.9774
#
#    TUITIONFEE_IN  Year
# 0         9744.0  2018
# 1         8568.0  2018
# 2         6900.0  2018
# 3        10714.0  2018
# 4        11068.0  2018

# %% [markdown]
# Concatenate and form a main dataframe

# %%
dfs = [df1, df2, df3, df4, df5, df6, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22, df23, df24, df25, df26]
maindf = pd.concat(dfs)

# %% [markdown]
# 6.  explore the new dataframe (# of observations, varibles, head, tail, sample, missing values, statistics,etc.)

# %%
maindf
# Out:
#         UNITID                                             INSTNM STABBR  \
# 0       100636                 Community College of the Air Force     AL
# 1       100654                           Alabama A & M University     AL
# 2       100663                University of Alabama at Birmingham     AL
# 3       100672             ALABAMA AVIATION AND TECHNICAL COLLEGE     AL
# 4       100690                                 Amridge University     AL
# 5       100706                University of Alabama in Huntsville     AL
# 6       100724                           Alabama State University     AL
# 7       100751                          The University of Alabama     AL
# 8       100760                  Central Alabama Community College     AL
# 9       100812                            Athens State University     AL
# 10      100830                    Auburn University at Montgomery     AL
# 11      100858                                  Auburn University     AL
# ...

# %%
maindf.reset_index(drop=True, inplace=True)
maindf
# Out:
#           UNITID                                             INSTNM STABBR  \
# 0         100636                 Community College of the Air Force     AL
# 1         100654                           Alabama A & M University     AL
# 2         100663                University of Alabama at Birmingham     AL
# 3         100672             ALABAMA AVIATION AND TECHNICAL COLLEGE     AL
# 4         100690                                 Amridge University     AL
# 5         100706                University of Alabama in Huntsville     AL
# 6         100724                           Alabama State University     AL
# 7         100751                          The University of Alabama     AL
# 8         100760                  Central Alabama Community College     AL
# 9         100812                            Athens State University     AL
# 10        100830                    Auburn University at Montgomery     AL
# ...

# %%
maindf.head()
# Out:
#    UNITID                                  INSTNM STABBR  REGION  ADM_RATE  \
# 0  100636      Community College of the Air Force     AL     0.0       NaN
# 1  100654                Alabama A & M University     AL     5.0       NaN
# 2  100663     University of Alabama at Birmingham     AL     5.0       NaN
# 3  100672  ALABAMA AVIATION AND TECHNICAL COLLEGE     AL     5.0       NaN
# 4  100690                      Amridge University     AL     5.0       NaN
#
#    TUITIONFEE_IN  Year
# 0            NaN  1996
# 1            NaN  1996
# 2            NaN  1996
# 3            NaN  1996
# 4            NaN  1996

# %%
maindf.tail()
# Out:
#           UNITID                                    INSTNM STABBR  REGION  \
# 163326  48511112         Georgia Military College - Dublin     GA     5.0
# 163327  48511113        Georgia Military College - Eastman     GA     5.0
# 163328  48616901  American College of Barbering - Florence     KY     5.0
# 163329  49005401      HCI College - Fort Lauderdale Campus     FL     5.0
# 163330  49146401          ABC Adult School - Cabrillo Lane     CA     8.0
#
#         ADM_RATE  TUITIONFEE_IN  Year
# 163326       NaN         6120.0  2018
# 163327       NaN         6120.0  2018
# 163328       NaN            NaN  2018
# 163329       NaN        21420.0  2018
# 163330       NaN            NaN  2018

# %%
maindf.sample(5)
# Out:
#           UNITID                              INSTNM STABBR  REGION  ADM_RATE  \
# 13408     414434          JON LOUIS SCHOOL OF BEAUTY     NY     2.0       NaN
# 95718   17355901      M State - Detroit Lakes Campus     MN     4.0       NaN
# 125853    466152  National American University-Tulsa     OK     6.0       NaN
# 54934     138983            Augusta State University     GA     5.0    0.6619
# 3895      204200       Mount Saint Joseph University     OH     3.0       NaN
#
#         TUITIONFEE_IN  Year
# 13408             NaN  1997
# 95718          5082.0  2009
# 125853        12315.0  2013
# 54934          2702.0  2004
# 3895              NaN  1996

# %%
maindf.isnull().sum()
# Out:
# UNITID                0
# INSTNM                0
# STABBR                0
# REGION                1
# ADM_RATE         118420
# TUITIONFEE_IN     84137
# Year                  0
# dtype: int64

# %%
maindf.dtypes
# Out:
# UNITID             int64
# INSTNM            object
# STABBR            object
# REGION           float64
# ADM_RATE         float64
# TUITIONFEE_IN    float64
# Year              object
# dtype: object

# %%
maindf['Year'] = maindf['Year'].apply(np.int64)

# %%
maindf.dtypes
# Out:
# UNITID             int64
# INSTNM            object
# STABBR            object
# REGION           float64
# ADM_RATE         float64
# TUITIONFEE_IN    float64
# Year               int64
# dtype: object

# %%
maindf.describe()
# Out:
#              UNITID         REGION      ADM_RATE  TUITIONFEE_IN           Year
# count  1.633310e+05  163330.000000  44911.000000   79194.000000  163331.000000
# mean   9.432395e+05       4.554693      0.692946   11665.505367    2007.249481
# std    4.571721e+06       2.189217      0.217062    9985.998016       6.608266
# min    1.006360e+05       0.000000      0.000000       0.000000    1996.000000
# 25%    1.633380e+05       3.000000      0.555000    3776.000000    2002.000000
# 50%    2.127800e+05       5.000000      0.717500    9285.000000    2008.000000
# 75%    4.075680e+05       6.000000      0.857100   16146.000000    2013.000000
# max    4.914640e+07       9.000000      1.000000   74787.000000    2018.000000

# %% [markdown]
# 7. Filter/query the dataframe to retrieve only rows that belong to UMBC

# %%
UMBCdf=maindf[maindf['INSTNM']=='University of Maryland-Baltimore County']
UMBCdf
# Out:
#         UNITID                                   INSTNM STABBR  REGION  \
# 2151    163268  University of Maryland-Baltimore County     MD     2.0
# 9056    163268  University of Maryland-Baltimore County     MD     2.0
# 15923   163268  University of Maryland-Baltimore County     MD     2.0
# 22598   163268  University of Maryland-Baltimore County     MD     2.0
# 29178   163268  University of Maryland-Baltimore County     MD     2.0
# 35821   163268  University of Maryland-Baltimore County     MD     2.0
# 42524   163268  University of Maryland-Baltimore County     MD     2.0
# 49156   163268  University of Maryland-Baltimore County     MD     2.0
# 55786   163268  University of Maryland-Baltimore County     MD     2.0
# 62522   163268  University of Maryland-Baltimore County     MD     2.0
# 69401   163268  University of Maryland-Baltimore County     MD     2.0
# 76332   163268  University of Maryland-Baltimore County     MD     2.0
# ...

# %% [markdown]
# 8. Explore this UMBC dataframe (# of observations, varibles, head, tail, sample, missing values, statistics,etc.)

# %%
type(UMBCdf)
# Out:
# pandas.core.frame.DataFrame

# %%
UMBCdf.head()
# Out:
#        UNITID                                   INSTNM STABBR  REGION  \
# 2151   163268  University of Maryland-Baltimore County     MD     2.0
# 9056   163268  University of Maryland-Baltimore County     MD     2.0
# 15923  163268  University of Maryland-Baltimore County     MD     2.0
# 22598  163268  University of Maryland-Baltimore County     MD     2.0
# 29178  163268  University of Maryland-Baltimore County     MD     2.0
#
#        ADM_RATE  TUITIONFEE_IN  Year
# 2151        NaN            NaN  1996
# 9056        NaN            NaN  1997
# 15923       NaN            NaN  1998
# 22598       NaN            NaN  1999
# 29178       NaN         5490.0  2000

# %%
UMBCdf.tail()
# Out:
#         UNITID                                   INSTNM STABBR  REGION  \
# 128353  163268  University of Maryland-Baltimore County     MD     2.0
# 136064  163268  University of Maryland-Baltimore County     MD     2.0
# 143685  163268  University of Maryland-Baltimore County     MD     2.0
# 150891  163268  University of Maryland-Baltimore County     MD     2.0
# 157940  163268  University of Maryland-Baltimore County     MD     2.0
#
#         ADM_RATE  TUITIONFEE_IN  Year
# 128353    0.5961        10384.0  2014
# 136064    0.5942        11006.0  2015
# 143685    0.5683        11264.0  2016
# 150891    0.6021        11518.0  2017
# 157940    0.5794        11778.0  2018

# %%
UMBCdf.sample(5)
# Out:
#         UNITID                                   INSTNM STABBR  REGION  \
# 22598   163268  University of Maryland-Baltimore County     MD     2.0
# 29178   163268  University of Maryland-Baltimore County     MD     2.0
# 90324   163268  University of Maryland-Baltimore County     MD     2.0
# 55786   163268  University of Maryland-Baltimore County     MD     2.0
# 120503  163268  University of Maryland-Baltimore County     MD     2.0
#
#         ADM_RATE  TUITIONFEE_IN  Year
# 22598        NaN            NaN  1999
# 29178        NaN         5490.0  2000
# 90324     0.6890         8872.0  2009
# 55786     0.7014         8020.0  2004
# 120503    0.6315        10068.0  2013

# %%
UMBCdf.isnull().sum()
# Out:
# UNITID           0
# INSTNM           0
# STABBR           0
# REGION           0
# ADM_RATE         5
# TUITIONFEE_IN    4
# Year             0
# dtype: int64

# %%
UMBCdf.dtypes
# Out:
# UNITID             int64
# INSTNM            object
# STABBR            object
# REGION           float64
# ADM_RATE         float64
# TUITIONFEE_IN    float64
# Year               int64
# dtype: object

# %%
UMBCdf.describe()
# Out:
#          UNITID  REGION   ADM_RATE  TUITIONFEE_IN        Year
# count      23.0    23.0  18.000000      19.000000    23.00000
# mean   163268.0     2.0   0.640694    9004.842105  2007.00000
# std         0.0     0.0   0.052728    1825.795421     6.78233
# min    163268.0     2.0   0.568300    5490.000000  1996.00000
# 25%    163268.0     2.0   0.597600    8270.000000  2001.50000
# 50%    163268.0     2.0   0.632100    8872.000000  2007.00000
# 75%    163268.0     2.0   0.689375   10226.000000  2012.50000
# max    163268.0     2.0   0.717400   11778.000000  2018.00000

# %% [markdown]
# 9. Plot UMBC's in-state tution overtime from 1996 to 2019 using Bar Chart

# %%
UMBCdf.plot(x="Year", y="TUITIONFEE_IN", kind="bar")

# %% [markdown]
# 10. Plot UMBC's in-state tution overtime from 1996 to 2019 using Line Chart

# %%
UMBCdf.plot(x="Year", y="TUITIONFEE_IN")
plt.show()

# %% [markdown]
# 11. UMBC tuition change percentage each year

# %% [markdown]
# a. Using as a list

# %%
#https://thispointer.com/pandas-convert-a-dataframe-column-into-a-list-using-series-to_list-or-numpy-ndarray-tolist-in-python/
tuitionfee = UMBCdf['TUITIONFEE_IN'].to_list()

# %%
#https://stackoverflow.com/questions/12700166/calculating-change-in-percentage-between-two-numbers-python
for a, b in zip(tuitionfee[::1], tuitionfee[1::1]):
    print(100 * (b - a) / a)
# Out:
# nan
# nan
# nan
# nan
# 7.6502732240437155
# 7.648054145516075
# 16.12700408676517
# 8.554412560909583
# 6.234413965087282
# 1.1971830985915493
# 0.9974483878450475
# 0.8268259072117593
# 1.0478359908883828
# 3.3701532912533816
# 3.227565151019518
# 3.137213478398648
# 3.11347808275297
# 3.1386571315057608
# 5.989984591679507
# 2.344175904052335
# 2.254971590909091
# 2.2573363431151243

# %% [markdown]
# b. Using pandas

# %%
#https://stackoverflow.com/questions/12700166/calculating-change-in-percentage-between-two-numbers-python

price_series = pd.Series(UMBCdf['TUITIONFEE_IN'])
pctchange = price_series.pct_change() * 100

# %%
pctchange
# Out:
# 2151            NaN
# 9056            NaN
# 15923           NaN
# 22598           NaN
# 29178           NaN
# 35821      7.650273
# 42524      7.648054
# 49156     16.127004
# 55786      8.554413
# 62522      6.234414
# 69401      1.197183
# 76332      0.997448
# 83291      0.826826
# 90324      1.047836
# 97506      3.370153
# 104960     3.227565
# 112672     3.137213
# 120503     3.113478
# 128353     3.138657
# 136064     5.989985
# 143685     2.344176
# 150891     2.254972
# 157940     2.257336
# Name: TUITIONFEE_IN, dtype: float64

# %% [markdown]
# Add the list of the percentages to the dataframe as a new column ("PCT_CHANGE")

# %%
UMBCdf['PCT_CHANGE'] = pctchange
# Out:
# C:\Users\shrut\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
UMBCdf
# Out:
#         UNITID                                   INSTNM STABBR  REGION  \
# 2151    163268  University of Maryland-Baltimore County     MD     2.0
# 9056    163268  University of Maryland-Baltimore County     MD     2.0
# 15923   163268  University of Maryland-Baltimore County     MD     2.0
# 22598   163268  University of Maryland-Baltimore County     MD     2.0
# 29178   163268  University of Maryland-Baltimore County     MD     2.0
# 35821   163268  University of Maryland-Baltimore County     MD     2.0
# 42524   163268  University of Maryland-Baltimore County     MD     2.0
# 49156   163268  University of Maryland-Baltimore County     MD     2.0
# 55786   163268  University of Maryland-Baltimore County     MD     2.0
# 62522   163268  University of Maryland-Baltimore County     MD     2.0
# 69401   163268  University of Maryland-Baltimore County     MD     2.0
# 76332   163268  University of Maryland-Baltimore County     MD     2.0
# ...

# %%
UMBCdf['PCT_CHANGE'] = UMBCdf['PCT_CHANGE'].round(2)
# Out:
# C:\Users\shrut\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
UMBCdf.tail()
# Out:
#         UNITID                                   INSTNM STABBR  REGION  \
# 128353  163268  University of Maryland-Baltimore County     MD     2.0
# 136064  163268  University of Maryland-Baltimore County     MD     2.0
# 143685  163268  University of Maryland-Baltimore County     MD     2.0
# 150891  163268  University of Maryland-Baltimore County     MD     2.0
# 157940  163268  University of Maryland-Baltimore County     MD     2.0
#
#         ADM_RATE  TUITIONFEE_IN  Year  PCT_CHANGE
# 128353    0.5961        10384.0  2014        3.14
# 136064    0.5942        11006.0  2015        5.99
# 143685    0.5683        11264.0  2016        2.34
# 150891    0.6021        11518.0  2017        2.25
# 157940    0.5794        11778.0  2018        2.26

# %% [markdown]
# 12. Plot tuition growth rate year over year - bar first, then line chart

# %%
UMBCdf.plot(x="Year", y="PCT_CHANGE", kind="bar")

# %%
UMBCdf.plot(x="Year", y="PCT_CHANGE")
plt.show()

# %%
price_series1 = pd.Series(maindf['TUITIONFEE_IN'])
pctchangemain = price_series1.pct_change() * 100

# %%
pctchangemain
# Out:
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15               NaN
# 16               NaN
# 17               NaN
# 18               NaN
# 19               NaN
# 20               NaN
# 21               NaN
# 22               NaN
# 23               NaN
# 24               NaN
# 25               NaN
# 26               NaN
# 27               NaN
# 28               NaN
# 29               NaN
#              ...
# 163301      0.000000
# 163302      0.000000
# 163303      0.000000
# 163304      0.000000
# 163305      0.000000
# 163306    -36.863283
# 163307      0.000000
# 163308      0.000000
# 163309      0.000000
# 163310      0.000000
# 163311      0.000000
# 163312      0.000000
# ...

# %% [markdown]
# 13. Filter/query the dataframe to retrieve only rows that belong to JHU

# %%
JHUdf=maindf[maindf['INSTNM']=='Johns Hopkins University']
JHUdf
# Out:
#         UNITID                    INSTNM STABBR  REGION  ADM_RATE  \
# 2139    162928  Johns Hopkins University     MD     2.0       NaN
# 9046    162928  Johns Hopkins University     MD     2.0       NaN
# 15914   162928  Johns Hopkins University     MD     2.0       NaN
# 22589   162928  Johns Hopkins University     MD     2.0       NaN
# 29169   162928  Johns Hopkins University     MD     2.0       NaN
# 35812   162928  Johns Hopkins University     MD     2.0    0.3431
# 42515   162928  Johns Hopkins University     MD     2.0    0.3506
# 49148   162928  Johns Hopkins University     MD     2.0    0.3060
# 55779   162928  Johns Hopkins University     MD     2.0    0.3071
# 62515   162928  Johns Hopkins University     MD     2.0    0.3509
# 69394   162928  Johns Hopkins University     MD     2.0    0.2792
# 76325   162928  Johns Hopkins University     MD     2.0    0.2571
# 83284   162928  Johns Hopkins University     MD     2.0    0.2609
# ...

# %%
JHUdf.head()
# Out:
#        UNITID                    INSTNM STABBR  REGION  ADM_RATE  \
# 2139   162928  Johns Hopkins University     MD     2.0       NaN
# 9046   162928  Johns Hopkins University     MD     2.0       NaN
# 15914  162928  Johns Hopkins University     MD     2.0       NaN
# 22589  162928  Johns Hopkins University     MD     2.0       NaN
# 29169  162928  Johns Hopkins University     MD     2.0       NaN
#
#        TUITIONFEE_IN  Year
# 2139             NaN  1996
# 9046             NaN  1997
# 15914            NaN  1998
# 22589            NaN  1999
# 29169        24930.0  2000

# %%
JHUdf.tail()
# Out:
#         UNITID                    INSTNM STABBR  REGION  ADM_RATE  \
# 128346  162928  Johns Hopkins University     MD     2.0    0.1608
# 136057  162928  Johns Hopkins University     MD     2.0    0.1412
# 143678  162928  Johns Hopkins University     MD     2.0    0.1284
# 150886  162928  Johns Hopkins University     MD     2.0    0.1254
# 157935  162928  Johns Hopkins University     MD     2.0    0.1148
#
#         TUITIONFEE_IN  Year
# 128346        47060.0  2014
# 136057        48710.0  2015
# 143678        50410.0  2016
# 150886        52170.0  2017
# 157935        53740.0  2018

# %%
JHUdf.sample(5)
# Out:
#         UNITID                    INSTNM STABBR  REGION  ADM_RATE  \
# 29169   162928  Johns Hopkins University     MD     2.0       NaN
# 97499   162928  Johns Hopkins University     MD     2.0    0.2225
# 2139    162928  Johns Hopkins University     MD     2.0       NaN
# 112665  162928  Johns Hopkins University     MD     2.0    0.1843
# 120496  162928  Johns Hopkins University     MD     2.0    0.1813
#
#         TUITIONFEE_IN  Year
# 29169         24930.0  2000
# 97499         40680.0  2010
# 2139              NaN  1996
# 112665        43390.0  2012
# 120496        45470.0  2013

# %%
JHUdf.isnull().sum()
# Out:
# UNITID           0
# INSTNM           0
# STABBR           0
# REGION           0
# ADM_RATE         5
# TUITIONFEE_IN    4
# Year             0
# dtype: int64

# %%
JHUdf.describe()
# Out:
#          UNITID  REGION   ADM_RATE  TUITIONFEE_IN        Year
# count      23.0    23.0  18.000000      19.000000    23.00000
# mean   162928.0     2.0   0.232544   38925.263158  2007.00000
# std         0.0     0.0   0.081533    9210.110609     6.78233
# min    162928.0     2.0   0.114800   24930.000000  1996.00000
# 25%    162928.0     2.0   0.165925   30880.000000  2001.50000
# 50%    162928.0     2.0   0.239800   39150.000000  2007.00000
# 75%    162928.0     2.0   0.299300   46265.000000  2012.50000
# max    162928.0     2.0   0.350900   53740.000000  2018.00000

# %% [markdown]
# 14. Plot JHU's in-state tuition overtime from 1996 to 2019.

# %%
JHUdf.plot(x="Year", y="TUITIONFEE_IN", kind="bar")

# %%
JHUdf.plot(x="Year", y="TUITIONFEE_IN")
plt.show()

# %% [markdown]
# 15. calculate the JHU tuition percentge growth

# %%
price_seriesjhu = pd.Series(JHUdf['TUITIONFEE_IN'])
pctchangejhu = price_seriesjhu.pct_change() * 100

# %%
pctchangejhu
# Out:
# 2139           NaN
# 9046           NaN
# 15914          NaN
# 22589          NaN
# 29169          NaN
# 35812     5.134376
# 42515     4.502098
# 49148     4.892296
# 55779     4.907762
# 62515     4.910418
# 69394     7.210626
# 76325     5.899705
# 83284     5.013928
# 90317     3.846154
# 97499     3.908046
# 104953    3.933137
# 112665    2.625355
# 120496    4.793731
# 128346    3.496811
# 136057    3.506162
# 143678    3.490043
# 150886    3.491371
# 157935    3.009392
# Name: TUITIONFEE_IN, dtype: float64

# %% [markdown]
# 16. Add the list of percentage changes to the dataframe as a new column ("PCT_CHANGE")

# %%
JHUdf['PCT_CHANGE'] = pctchangejhu
# Out:
# C:\Users\shrut\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
JHUdf.tail()
# Out:
#         UNITID                    INSTNM STABBR  REGION  ADM_RATE  \
# 128346  162928  Johns Hopkins University     MD     2.0    0.1608
# 136057  162928  Johns Hopkins University     MD     2.0    0.1412
# 143678  162928  Johns Hopkins University     MD     2.0    0.1284
# 150886  162928  Johns Hopkins University     MD     2.0    0.1254
# 157935  162928  Johns Hopkins University     MD     2.0    0.1148
#
#         TUITIONFEE_IN  Year  PCT_CHANGE
# 128346        47060.0  2014    3.496811
# 136057        48710.0  2015    3.506162
# 143678        50410.0  2016    3.490043
# 150886        52170.0  2017    3.491371
# 157935        53740.0  2018    3.009392

# %%
JHUdf['PCT_CHANGE'] = JHUdf['PCT_CHANGE'].round(2)
# Out:
# C:\Users\shrut\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
JHUdf.tail()
# Out:
#         UNITID                    INSTNM STABBR  REGION  ADM_RATE  \
# 128346  162928  Johns Hopkins University     MD     2.0    0.1608
# 136057  162928  Johns Hopkins University     MD     2.0    0.1412
# 143678  162928  Johns Hopkins University     MD     2.0    0.1284
# 150886  162928  Johns Hopkins University     MD     2.0    0.1254
# 157935  162928  Johns Hopkins University     MD     2.0    0.1148
#
#         TUITIONFEE_IN  Year  PCT_CHANGE
# 128346        47060.0  2014        3.50
# 136057        48710.0  2015        3.51
# 143678        50410.0  2016        3.49
# 150886        52170.0  2017        3.49
# 157935        53740.0  2018        3.01

# %% [markdown]
# 17. Make a bar plot of the JHU percentage changes tuitions over time

# %%
JHUdf.plot(x="Year", y="PCT_CHANGE", kind="bar")

# %%
JHUdf.plot(x="Year", y="PCT_CHANGE")
plt.show()

# %% [markdown]
# 18. combine the two datasets using the common key of YEAR

# %%
umbc2 = UMBCdf.filter(['Year', 'PCT_CHANGE'])
umbc2
# Out:
#         Year  PCT_CHANGE
# 2151    1996         NaN
# 9056    1997         NaN
# 15923   1998         NaN
# 22598   1999         NaN
# 29178   2000         NaN
# 35821   2001        7.65
# 42524   2002        7.65
# 49156   2003       16.13
# 55786   2004        8.55
# 62522   2005        6.23
# 69401   2006        1.20
# 76332   2007        1.00
# 83291   2008        0.83
# 90324   2009        1.05
# 97506   2010        3.37
# 104960  2011        3.23
# 112672  2012        3.14
# 120503  2013        3.11
# 128353  2014        3.14
# 136064  2015        5.99
# 143685  2016        2.34
# 150891  2017        2.25
# 157940  2018        2.26

# %%
type(umbc2)
# Out:
# pandas.core.frame.DataFrame

# %%
jhu2 = JHUdf.filter(['Year', 'PCT_CHANGE'])
jhu2
# Out:
#         Year  PCT_CHANGE
# 2139    1996         NaN
# 9046    1997         NaN
# 15914   1998         NaN
# 22589   1999         NaN
# 29169   2000         NaN
# 35812   2001        5.13
# 42515   2002        4.50
# 49148   2003        4.89
# 55779   2004        4.91
# 62515   2005        4.91
# 69394   2006        7.21
# 76325   2007        5.90
# 83284   2008        5.01
# 90317   2009        3.85
# 97499   2010        3.91
# 104953  2011        3.93
# 112665  2012        2.63
# 120496  2013        4.79
# 128346  2014        3.50
# 136057  2015        3.51
# 143678  2016        3.49
# 150886  2017        3.49
# 157935  2018        3.01

# %%
#https://www.geeksforgeeks.org/how-to-rename-columns-in-pandas-dataframe/
umbc2.rename(columns = {'PCT_CHANGE':'UMBC_PCT'}, inplace = True)

# %%
umbc2
# Out:
#         Year  UMBC_PCT
# 2151    1996       NaN
# 9056    1997       NaN
# 15923   1998       NaN
# 22598   1999       NaN
# 29178   2000       NaN
# 35821   2001      7.65
# 42524   2002      7.65
# 49156   2003     16.13
# 55786   2004      8.55
# 62522   2005      6.23
# 69401   2006      1.20
# 76332   2007      1.00
# 83291   2008      0.83
# 90324   2009      1.05
# 97506   2010      3.37
# 104960  2011      3.23
# 112672  2012      3.14
# 120503  2013      3.11
# 128353  2014      3.14
# 136064  2015      5.99
# 143685  2016      2.34
# 150891  2017      2.25
# 157940  2018      2.26

# %%
jhu2.rename(columns = {'PCT_CHANGE':'JHU_PCT'}, inplace = True)

# %%
jhu2
# Out:
#         Year  JHU_PCT
# 2139    1996      NaN
# 9046    1997      NaN
# 15914   1998      NaN
# 22589   1999      NaN
# 29169   2000      NaN
# 35812   2001     5.13
# 42515   2002     4.50
# 49148   2003     4.89
# 55779   2004     4.91
# 62515   2005     4.91
# 69394   2006     7.21
# 76325   2007     5.90
# 83284   2008     5.01
# 90317   2009     3.85
# 97499   2010     3.91
# 104953  2011     3.93
# 112665  2012     2.63
# 120496  2013     4.79
# 128346  2014     3.50
# 136057  2015     3.51
# 143678  2016     3.49
# 150886  2017     3.49
# 157935  2018     3.01

# %% [markdown]
# Merge the two dataframes

# %%
#https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
result = pd.merge(umbc2, jhu2, on='Year')
type(result)
# Out:
# pandas.core.frame.DataFrame

# %%
result
# Out:
#     Year  UMBC_PCT  JHU_PCT
# 0   1996       NaN      NaN
# 1   1997       NaN      NaN
# 2   1998       NaN      NaN
# 3   1999       NaN      NaN
# 4   2000       NaN      NaN
# 5   2001      7.65     5.13
# 6   2002      7.65     4.50
# 7   2003     16.13     4.89
# 8   2004      8.55     4.91
# 9   2005      6.23     4.91
# 10  2006      1.20     7.21
# 11  2007      1.00     5.90
# 12  2008      0.83     5.01
# 13  2009      1.05     3.85
# 14  2010      3.37     3.91
# 15  2011      3.23     3.93
# 16  2012      3.14     2.63
# 17  2013      3.11     4.79
# 18  2014      3.14     3.50
# 19  2015      5.99     3.51
# 20  2016      2.34     3.49
# 21  2017      2.25     3.49
# 22  2018      2.26     3.01

# %% [markdown]
# Plot UMBC and JHU separately on the same plot

# %%
#https://stackoverflow.com/questions/42128467/matplotlib-plot-multiple-columns-of-pandas-data-frame-on-the-bar-chart
result.plot(x="Year", y=["UMBC_PCT", "JHU_PCT"], kind="bar")

# %%
result.plot(x="Year", y=["UMBC_PCT", "JHU_PCT"])
plt.show()

# %% [markdown]
# 20. document your observation/conclusion of the comparison plots (bar/line)
#
# Based on the observation of the plots, there has been drastic decrease and increase in the percentage when it comes to UMBC instate tuitionfee growth from 2002 to 2010 whereas there has been small decrease and increase in the percentage of instate tuitionfee growth of JHU.
