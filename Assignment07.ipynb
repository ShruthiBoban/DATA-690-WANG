# %% [markdown]
# ## Assignment 07
# You can use the local Jupyter environment if you are not comfortable with Colab for this assignment.
#
# The first half of this assignment is a repeat of assignment 05.
#
# This gives you a chance to refresh.
#
# The second half is new and gives you a chance to perform additional practices.
#
# You also get a chance to use some of the Python libraries and techniques.
#
# You will unzip the zip file manually in preparation for this assignment.
#
# The link to the zip file is (you have already used it in your assignment 5):
#
# https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data.zip
#
# After unzipping, You will have all files in one folder named "CollegeScorecard_Raw_Data"
#
# The folder contains the yearly data files from 1996 to 2019 school years.
#
# if you are using your local environment, I suggest you create a new folder call "Assignment7" and place the Notebook file and the data folder under it.
#
# Assignment7/
#     - assignment_07.ipynb
#     - CollegeScorecard_Raw_Data/
#         - ...
#         - 'MERGED1996_97_PP.csv',
#         - 'MERGED2015_16_PP.csv',
#         - ...
#         - 'MERGED2017_18_PP.csv'

# %% [markdown]
# 1. Import libraries

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure 
import numpy as np

# %% [markdown]
# 2. Display the current workin directory

# %%
os.getcwd()
# Out:
# 'C:\\Users\\shrut\\Assignment07'

# %% [markdown]
# 3. Generate a list of files in a directory/folder

# %%
DATA_FOLDER = "../Assignment07/CollegeScorecard_Raw_Data/"
file_list = os.listdir(DATA_FOLDER)
file_list
# Out:
# ['.ipynb_checkpoints',
#  'a.DS_Store',
#  'Crosswalks.zip',
#  'data.yaml',
#  'MERGED1996_97_PP.csv',
#  'MERGED1997_98_PP.csv',
#  'MERGED1998_99_PP.csv',
#  'MERGED1999_00_PP.csv',
#  'MERGED2000_01_PP.csv',
#  'MERGED2001_02_PP.csv',
#  'MERGED2002_03_PP.csv',
#  'MERGED2003_04_PP.csv',
#  'MERGED2004_05_PP.csv',
#  'MERGED2005_06_PP.csv',
#  'MERGED2006_07_PP.csv',
#  'MERGED2007_08_PP.csv',
#  'MERGED2008_09_PP.csv',
#  'MERGED2009_10_PP.csv',
#  'MERGED2010_11_PP.csv',
#  'MERGED2011_12_PP.csv',
#  'MERGED2012_13_PP.csv',
#  'MERGED2013_14_PP.csv',
#  'MERGED2014_15_PP.csv',
#  'MERGED2015_16_PP.csv',
#  'MERGED2016_17_PP.csv',
#  'MERGED2017_18_PP.csv',
#  'MERGED2018_19_PP.csv']

# %% [markdown]
# 4. Remove unwanted files and keep the files that have "merged" mentioned in them

# %%
file_name_list = [x for x in file_list if x.endswith(".csv")]
file_name_list
# Out:
# ['MERGED1996_97_PP.csv',
#  'MERGED1997_98_PP.csv',
#  'MERGED1998_99_PP.csv',
#  'MERGED1999_00_PP.csv',
#  'MERGED2000_01_PP.csv',
#  'MERGED2001_02_PP.csv',
#  'MERGED2002_03_PP.csv',
#  'MERGED2003_04_PP.csv',
#  'MERGED2004_05_PP.csv',
#  'MERGED2005_06_PP.csv',
#  'MERGED2006_07_PP.csv',
#  'MERGED2007_08_PP.csv',
#  'MERGED2008_09_PP.csv',
#  'MERGED2009_10_PP.csv',
#  'MERGED2010_11_PP.csv',
#  'MERGED2011_12_PP.csv',
#  'MERGED2012_13_PP.csv',
#  'MERGED2013_14_PP.csv',
#  'MERGED2014_15_PP.csv',
#  'MERGED2015_16_PP.csv',
#  'MERGED2016_17_PP.csv',
#  'MERGED2017_18_PP.csv',
#  'MERGED2018_19_PP.csv']

# %% [markdown]
# 5. Use an empty list and append the yearly dataframes to the list and finally concatenate them to a single dataframe

# %%
COLUMN_LIST = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"]
df_list = []

for file in file_name_list:
    print("Reading file " + file + " ......")
    tmp_df = pd.read_csv(DATA_FOLDER + file, usecols=COLUMN_LIST)
    tmp_df["YEAR"] = file[6:13]
    df_list.append(tmp_df)
    
df = pd.concat(df_list, ignore_index = True)
df.info()
# Out:
# Reading file MERGED1996_97_PP.csv ......
# Reading file MERGED1997_98_PP.csv ......
# Reading file MERGED1998_99_PP.csv ......
# Reading file MERGED1999_00_PP.csv ......
# Reading file MERGED2000_01_PP.csv ......
# Reading file MERGED2001_02_PP.csv ......
# Reading file MERGED2002_03_PP.csv ......
# Reading file MERGED2003_04_PP.csv ......
# Reading file MERGED2004_05_PP.csv ......
# Reading file MERGED2005_06_PP.csv ......
# Reading file MERGED2006_07_PP.csv ......
# Reading file MERGED2007_08_PP.csv ......
# Reading file MERGED2008_09_PP.csv ......
# Reading file MERGED2009_10_PP.csv ......
# Reading file MERGED2010_11_PP.csv ......
# Reading file MERGED2011_12_PP.csv ......
# Reading file MERGED2012_13_PP.csv ......
# Reading file MERGED2013_14_PP.csv ......
# Reading file MERGED2014_15_PP.csv ......
# Reading file MERGED2015_16_PP.csv ......
# Reading file MERGED2016_17_PP.csv ......
# Reading file MERGED2017_18_PP.csv ......
# Reading file MERGED2018_19_PP.csv ......
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163331 entries, 0 to 163330
# Data columns (total 7 columns):
# UNITID           163331 non-null int64
# INSTNM           163331 non-null object
# STABBR           163331 non-null object
# REGION           163330 non-null float64
# ADM_RATE         44911 non-null float64
# TUITIONFEE_IN    79194 non-null float64
# YEAR             163331 non-null object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 8.7+ MB

# %%
df[df["YEAR"] == "2001_02"]
# Out:
#        UNITID                                             INSTNM STABBR  \
# 33906  100636                 Community College of the Air Force     AL
# 33907  100654                           Alabama A & M University     AL
# 33908  100663                University of Alabama at Birmingham     AL
# 33909  100690                                 Amridge University     AL
# 33910  100706                University of Alabama in Huntsville     AL
# 33911  100724                           Alabama State University     AL
# 33912  100751                          The University of Alabama     AL
# 33913  100760                  Central Alabama Community College     AL
# 33914  100812                            Athens State University     AL
# 33915  100830                    Auburn University at Montgomery     AL
# 33916  100858                                  Auburn University     AL
# 33917  100919     Lawson State Community College-Bessemer Campus     AL
# 33918  100937                        Birmingham-Southern College     AL
# 33919  100973   Shelton State Community College-C A Fredd Campus     AL
# 33920  101028             Chattahoochee Valley Community College     AL
# 33921  101073                          Concordia College Alabama     AL
# 33922  101107  LURLEEN B WALLACE COMMUNITY COLLEGE-MACARTHUR ...     AL
# 33923  101116                        South University-Montgomery     AL
# 33924  101143                 Enterprise State Community College     AL
# 33925  101161                  Coastal Alabama Community College     AL
# 33926  101189                                Faulkner University     AL
# 33927  101198                     FAULKNER UNIVERSITY-BIRMINGHAM     AL
# 33928  101213                                FAULKNER UNIVERSITY     AL
# 33929  101231                           Gadsden Business College     AL
# 33930  101240                    Gadsden State Community College     AL
# 33931  101268                  GADSDEN BUSINESS COLLEGE-ANNISTON     AL
# 33932  101286          George C Wallace Community College-Dothan     AL
# 33933  101295  George C Wallace State Community College-Hance...     AL
# 33934  101301     George C Wallace State Community College-Selma     AL
# 33935  101347       GADSDEN STATE COMMUNITY COLLEGE-AYERS CAMPUS     AL
# ...       ...                                                ...    ...
# 40601  440518             STRAYER UNIVERSITY-OWINGS MILLS CAMPUS     MD
# 40602  440527                   STRAYER UNIVERSITY-ONLINE CAMPUS     VA
# 40603  440554  DEVRY UNIVERSITY KELLER GRADUATE SCHOOL OF MAN...     GA
# 40604  440563  DEVRY UNIVERSITY KELLER GRADUATE SCHOOL OF MAN...     OH
# 40605  440572  DeVry University's Keller Graduate School of M...     OH
# 40606  440581  DeVry University's Keller Graduate School of M...     TX
# 40607  440615                     Middle Georgia College-Eastman     GA
# 40608  440642                  ITT Technical Institute-Levittown     PA
# 40609  440651                                     Atenas College     PR
# 40610  440660                       UNION INSTITUTE & UNIVERSITY     VT
# 40611  440679                      Ross Medical Education Center     MI
# 40612  440697  DEVRY UNIVERSITY KELLER GRADUATE SCHOOL OF MAN...     FL
# 40613  440703  DEVRY UNIVERSITY KELLER GRADUATE SCHOOL OF MAN...     WA
# 40614  440712                       UNION INSTITUTE & UNIVERSITY     VT
# 40615  440721  Southwest Skill Center-Campus of Estrella Moun...     AZ
# 40616  440730                    Onondaga Cortland Madison BOCES     NY
# 40617  440749  National American University-Ellsworth AFB Ext...     SD
# 40618  440758      National American University-Albuquerque West     NM
# 40619  440767       National American University-Brooklyn Center     MN
# 40620  440776                  Interactive College of Technology     TX
# 40621  440785     NEW ENGLAND CULINARY INST-H L STOUTT COMM COLL     VI
# 40622  440800                        Miami Ad School-Minneapolis     MN
# 40623  440819                      Miami Ad School-San Francisco     CA
# 40624  440837                Winner Institute of Arts & Sciences     PA
# 40625  440846                              Milan Institute-Boise     ID
# 40626  440855                           Milan Institute-Amarillo     TX
# 40627  440864                                    Trinity College     CA
# 40628  440873                         Vatterott College-Dividend     TN
# 40629  440882                            Vatterott College-Tulsa     OK
# 40630  440891                          Vatterott College-Wichita     KS
#
#        REGION  ADM_RATE  TUITIONFEE_IN     YEAR
# 33906     0.0       NaN            NaN  2001_02
# 33907     5.0    0.7505         4664.0  2001_02
# 33908     5.0    0.9098         3640.0  2001_02
# 33909     5.0       NaN            NaN  2001_02
# 33910     5.0    0.8381         3536.0  2001_02
# 33911     5.0       NaN         2904.0  2001_02
# 33912     5.0    0.7948         3292.0  2001_02
# 33913     5.0       NaN         2040.0  2001_02
# 33914     5.0       NaN            NaN  2001_02
# 33915     5.0       NaN         3210.0  2001_02
# 33916     5.0    0.7594         3380.0  2001_02
# 33917     5.0       NaN         1718.0  2001_02
# 33918     5.0    0.9179        16810.0  2001_02
# 33919     5.0       NaN         2040.0  2001_02
# 33920     5.0       NaN         2040.0  2001_02
# 33921     5.0       NaN         5954.0  2001_02
# 33922     5.0       NaN         1680.0  2001_02
# 33923     5.0    1.0000         8685.0  2001_02
# 33924     5.0       NaN         2040.0  2001_02
# 33925     5.0       NaN         1896.0  2001_02
# 33926     5.0    0.7086         8700.0  2001_02
# 33927     5.0       NaN         4320.0  2001_02
# 33928     5.0    0.8727         3840.0  2001_02
# 33929     5.0       NaN            NaN  2001_02
# 33930     5.0       NaN         1680.0  2001_02
# 33931     5.0       NaN            NaN  2001_02
# 33932     5.0       NaN         2040.0  2001_02
# 33933     5.0       NaN         1768.0  2001_02
# 33934     5.0       NaN         2040.0  2001_02
# 33935     5.0       NaN         2448.0  2001_02
# ...       ...       ...            ...      ...
# 40601     2.0       NaN         8789.0  2001_02
# 40602     5.0       NaN         8789.0  2001_02
# 40603     5.0       NaN            NaN  2001_02
# 40604     3.0       NaN            NaN  2001_02
# 40605     3.0       NaN            NaN  2001_02
# 40606     6.0       NaN            NaN  2001_02
# 40607     5.0       NaN         1249.0  2001_02
# 40608     2.0    0.9683        11704.0  2001_02
# 40609     9.0       NaN            NaN  2001_02
# 40610     1.0       NaN         9426.0  2001_02
# 40611     3.0    0.2443            NaN  2001_02
# 40612     5.0       NaN            NaN  2001_02
# 40613     8.0       NaN            NaN  2001_02
# 40614     1.0       NaN         9080.0  2001_02
# 40615     6.0       NaN            NaN  2001_02
# 40616     2.0       NaN            NaN  2001_02
# 40617     4.0       NaN         4170.0  2001_02
# 40618     6.0       NaN         7230.0  2001_02
# 40619     4.0       NaN         9030.0  2001_02
# 40620     6.0       NaN            NaN  2001_02
# 40621     9.0    1.0000         9940.0  2001_02
# 40622     4.0       NaN            NaN  2001_02
# 40623     8.0       NaN            NaN  2001_02
# 40624     2.0       NaN        12305.0  2001_02
# 40625     7.0    1.0000            NaN  2001_02
# 40626     6.0    1.0000            NaN  2001_02
# 40627     8.0    1.0000            NaN  2001_02
# 40628     5.0    0.9091         7520.0  2001_02
# 40629     6.0    0.9106         6715.0  2001_02
# 40630     4.0    0.8654         8380.0  2001_02
#
# [6725 rows x 7 columns]

# %% [markdown]
# 6.  explore the new dataframe (# of observations, varibles, head, tail, sample, missing values, statistics,etc.)

# %%
df
# Out:
#           UNITID                                             INSTNM STABBR  \
# 0         100636                 Community College of the Air Force     AL
# 1         100654                           Alabama A & M University     AL
# 2         100663                University of Alabama at Birmingham     AL
# 3         100672             ALABAMA AVIATION AND TECHNICAL COLLEGE     AL
# 4         100690                                 Amridge University     AL
# 5         100706                University of Alabama in Huntsville     AL
# 6         100724                           Alabama State University     AL
# 7         100751                          The University of Alabama     AL
# 8         100760                  Central Alabama Community College     AL
# 9         100812                            Athens State University     AL
# 10        100830                    Auburn University at Montgomery     AL
# 11        100858                                  Auburn University     AL
# 12        100919     Lawson State Community College-Bessemer Campus     AL
# 13        100937                        Birmingham-Southern College     AL
# 14        100964       BEVILL STATE COMMUNITY COLLEGE-BREWER CAMPUS     AL
# 15        101019                  CHARLES ACADEMY OF BEAUTY CULTURE     AL
# 16        101028             Chattahoochee Valley Community College     AL
# 17        101037            CHAUNCEY SPARKS STATE TECHNICAL COLLEGE     AL
# 18        101073                          Concordia College Alabama     AL
# 19        101107  LURLEEN B WALLACE COMMUNITY COLLEGE-MACARTHUR ...     AL
# 20        101116                        South University-Montgomery     AL
# 21        101143                 Enterprise State Community College     AL
# 22        101161                  Coastal Alabama Community College     AL
# 23        101189                                Faulkner University     AL
# 24        101198                     FAULKNER UNIVERSITY-BIRMINGHAM     AL
# 25        101204                       FAULKNER UNIVERSITY-FLORENCE     AL
# 26        101213                                FAULKNER UNIVERSITY     AL
# 27        101231                           Gadsden Business College     AL
# 28        101240                    Gadsden State Community College     AL
# 29        101268                  GADSDEN BUSINESS COLLEGE-ANNISTON     AL
# ...          ...                                                ...    ...
# 163301  48133101             Sharp Edgez Barber Institute - Buffalo     NY
# 163302  48137701            Grace College of Barbering - Greensboro     NC
# 163303  48154401  National Personal Training Institute of Cleveland     OH
# 163304  48305401             Barber School of Pittsburgh - Ambridge     PA
# 163305  48312401                 Arizona State University at Tucson     AZ
# 163306  48312402  Arizona State University - ASU Colleges at Lak...     AZ
# 163307  48312403        Arizona State University at The Gila Valley     AZ
# 163308  48312404                   Arizona State University at Yuma     AZ
# 163309  48312405                   Arizona State University - Pinal     AZ
# 163310  48312406                 Arizona State University - Cochise     AZ
# 163311  48379901       East-West Healing Arts Institute - Milwaukee     WI
# 163312  48385001                 Alliance Computing Solutions - NYC     NY
# 163313  48387801  Bay Area Medical Academy - San Jose Satellite ...     CA
# 163314  48400201           High Desert Medical College - Bakerfield     CA
# 163315  48511101                 Georgia Military College - Zebulon     GA
# 163316  48511102                  Georgia Military College - Albany     GA
# 163317  48511103                Georgia Military College - Valdosta     GA
# 163318  48511104                 Georgia Military College - Augusta     GA
# 163319  48511105                Georgia Military College - Fairburn     GA
# 163320  48511106                  Georgia Military College - Robins     GA
# 163321  48511107                Georgia Military College - Columbus     GA
# 163322  48511108            Georgia Military College - Sandersville     GA
# 163323  48511109                 Georgia Military College - Madison     GA
# 163324  48511110          Georgia Military College - Stone Mountain     GA
# 163325  48511111            Georgia Military College - Fayetteville     GA
# 163326  48511112                  Georgia Military College - Dublin     GA
# 163327  48511113                 Georgia Military College - Eastman     GA
# 163328  48616901           American College of Barbering - Florence     KY
# 163329  49005401               HCI College - Fort Lauderdale Campus     FL
# 163330  49146401                   ABC Adult School - Cabrillo Lane     CA
#
#         REGION  ADM_RATE  TUITIONFEE_IN     YEAR
# 0          0.0       NaN            NaN  1996_97
# 1          5.0       NaN            NaN  1996_97
# 2          5.0       NaN            NaN  1996_97
# 3          5.0       NaN            NaN  1996_97
# 4          5.0       NaN            NaN  1996_97
# 5          5.0       NaN            NaN  1996_97
# 6          5.0       NaN            NaN  1996_97
# 7          5.0       NaN            NaN  1996_97
# 8          5.0       NaN            NaN  1996_97
# 9          5.0       NaN            NaN  1996_97
# 10         5.0       NaN            NaN  1996_97
# 11         5.0       NaN            NaN  1996_97
# 12         5.0       NaN            NaN  1996_97
# 13         5.0       NaN            NaN  1996_97
# 14         5.0       NaN            NaN  1996_97
# 15         5.0       NaN            NaN  1996_97
# 16         5.0       NaN            NaN  1996_97
# 17         5.0       NaN            NaN  1996_97
# 18         5.0       NaN            NaN  1996_97
# 19         5.0       NaN            NaN  1996_97
# 20         5.0       NaN            NaN  1996_97
# 21         5.0       NaN            NaN  1996_97
# 22         5.0       NaN            NaN  1996_97
# 23         5.0       NaN            NaN  1996_97
# 24         5.0       NaN            NaN  1996_97
# 25         5.0       NaN            NaN  1996_97
# 26         5.0       NaN            NaN  1996_97
# 27         5.0       NaN            NaN  1996_97
# 28         5.0       NaN            NaN  1996_97
# 29         5.0       NaN            NaN  1996_97
# ...        ...       ...            ...      ...
# 163301     2.0       NaN            NaN  2018_19
# 163302     5.0       NaN            NaN  2018_19
# 163303     3.0       NaN            NaN  2018_19
# 163304     2.0       NaN            NaN  2018_19
# 163305     6.0       NaN            NaN  2018_19
# 163306     6.0       NaN         6904.0  2018_19
# 163307     6.0       NaN            NaN  2018_19
# 163308     6.0       NaN            NaN  2018_19
# 163309     6.0       NaN            NaN  2018_19
# 163310     6.0       NaN            NaN  2018_19
# 163311     3.0       NaN            NaN  2018_19
# 163312     2.0       NaN            NaN  2018_19
# 163313     8.0       NaN            NaN  2018_19
# 163314     8.0       NaN            NaN  2018_19
# 163315     5.0       NaN         6120.0  2018_19
# 163316     5.0       NaN         6120.0  2018_19
# 163317     5.0       NaN         5760.0  2018_19
# 163318     5.0       NaN         5940.0  2018_19
# 163319     5.0       NaN         6120.0  2018_19
# 163320     5.0       NaN         5940.0  2018_19
# 163321     5.0       NaN         6120.0  2018_19
# 163322     5.0       NaN         6120.0  2018_19
# 163323     5.0       NaN         6120.0  2018_19
# 163324     5.0       NaN         6120.0  2018_19
# 163325     5.0       NaN         6120.0  2018_19
# 163326     5.0       NaN         6120.0  2018_19
# 163327     5.0       NaN         6120.0  2018_19
# 163328     5.0       NaN            NaN  2018_19
# 163329     5.0       NaN        21420.0  2018_19
# 163330     8.0       NaN            NaN  2018_19
#
# [163331 rows x 7 columns]

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#           UNITID                                             INSTNM STABBR  \
# 0         100636                 Community College of the Air Force     AL
# 1         100654                           Alabama A & M University     AL
# 2         100663                University of Alabama at Birmingham     AL
# 3         100672             ALABAMA AVIATION AND TECHNICAL COLLEGE     AL
# 4         100690                                 Amridge University     AL
# 5         100706                University of Alabama in Huntsville     AL
# 6         100724                           Alabama State University     AL
# 7         100751                          The University of Alabama     AL
# 8         100760                  Central Alabama Community College     AL
# 9         100812                            Athens State University     AL
# 10        100830                    Auburn University at Montgomery     AL
# 11        100858                                  Auburn University     AL
# 12        100919     Lawson State Community College-Bessemer Campus     AL
# 13        100937                        Birmingham-Southern College     AL
# 14        100964       BEVILL STATE COMMUNITY COLLEGE-BREWER CAMPUS     AL
# 15        101019                  CHARLES ACADEMY OF BEAUTY CULTURE     AL
# 16        101028             Chattahoochee Valley Community College     AL
# 17        101037            CHAUNCEY SPARKS STATE TECHNICAL COLLEGE     AL
# 18        101073                          Concordia College Alabama     AL
# 19        101107  LURLEEN B WALLACE COMMUNITY COLLEGE-MACARTHUR ...     AL
# 20        101116                        South University-Montgomery     AL
# 21        101143                 Enterprise State Community College     AL
# 22        101161                  Coastal Alabama Community College     AL
# 23        101189                                Faulkner University     AL
# 24        101198                     FAULKNER UNIVERSITY-BIRMINGHAM     AL
# 25        101204                       FAULKNER UNIVERSITY-FLORENCE     AL
# 26        101213                                FAULKNER UNIVERSITY     AL
# 27        101231                           Gadsden Business College     AL
# 28        101240                    Gadsden State Community College     AL
# 29        101268                  GADSDEN BUSINESS COLLEGE-ANNISTON     AL
# ...          ...                                                ...    ...
# 163301  48133101             Sharp Edgez Barber Institute - Buffalo     NY
# 163302  48137701            Grace College of Barbering - Greensboro     NC
# 163303  48154401  National Personal Training Institute of Cleveland     OH
# 163304  48305401             Barber School of Pittsburgh - Ambridge     PA
# 163305  48312401                 Arizona State University at Tucson     AZ
# 163306  48312402  Arizona State University - ASU Colleges at Lak...     AZ
# 163307  48312403        Arizona State University at The Gila Valley     AZ
# 163308  48312404                   Arizona State University at Yuma     AZ
# 163309  48312405                   Arizona State University - Pinal     AZ
# 163310  48312406                 Arizona State University - Cochise     AZ
# 163311  48379901       East-West Healing Arts Institute - Milwaukee     WI
# 163312  48385001                 Alliance Computing Solutions - NYC     NY
# 163313  48387801  Bay Area Medical Academy - San Jose Satellite ...     CA
# 163314  48400201           High Desert Medical College - Bakerfield     CA
# 163315  48511101                 Georgia Military College - Zebulon     GA
# 163316  48511102                  Georgia Military College - Albany     GA
# 163317  48511103                Georgia Military College - Valdosta     GA
# 163318  48511104                 Georgia Military College - Augusta     GA
# 163319  48511105                Georgia Military College - Fairburn     GA
# 163320  48511106                  Georgia Military College - Robins     GA
# 163321  48511107                Georgia Military College - Columbus     GA
# 163322  48511108            Georgia Military College - Sandersville     GA
# 163323  48511109                 Georgia Military College - Madison     GA
# 163324  48511110          Georgia Military College - Stone Mountain     GA
# 163325  48511111            Georgia Military College - Fayetteville     GA
# 163326  48511112                  Georgia Military College - Dublin     GA
# 163327  48511113                 Georgia Military College - Eastman     GA
# 163328  48616901           American College of Barbering - Florence     KY
# 163329  49005401               HCI College - Fort Lauderdale Campus     FL
# 163330  49146401                   ABC Adult School - Cabrillo Lane     CA
#
#         REGION  ADM_RATE  TUITIONFEE_IN     YEAR
# 0          0.0       NaN            NaN  1996_97
# 1          5.0       NaN            NaN  1996_97
# 2          5.0       NaN            NaN  1996_97
# 3          5.0       NaN            NaN  1996_97
# 4          5.0       NaN            NaN  1996_97
# 5          5.0       NaN            NaN  1996_97
# 6          5.0       NaN            NaN  1996_97
# 7          5.0       NaN            NaN  1996_97
# 8          5.0       NaN            NaN  1996_97
# 9          5.0       NaN            NaN  1996_97
# 10         5.0       NaN            NaN  1996_97
# 11         5.0       NaN            NaN  1996_97
# 12         5.0       NaN            NaN  1996_97
# 13         5.0       NaN            NaN  1996_97
# 14         5.0       NaN            NaN  1996_97
# 15         5.0       NaN            NaN  1996_97
# 16         5.0       NaN            NaN  1996_97
# 17         5.0       NaN            NaN  1996_97
# 18         5.0       NaN            NaN  1996_97
# 19         5.0       NaN            NaN  1996_97
# 20         5.0       NaN            NaN  1996_97
# 21         5.0       NaN            NaN  1996_97
# 22         5.0       NaN            NaN  1996_97
# 23         5.0       NaN            NaN  1996_97
# 24         5.0       NaN            NaN  1996_97
# 25         5.0       NaN            NaN  1996_97
# 26         5.0       NaN            NaN  1996_97
# 27         5.0       NaN            NaN  1996_97
# 28         5.0       NaN            NaN  1996_97
# 29         5.0       NaN            NaN  1996_97
# ...        ...       ...            ...      ...
# 163301     2.0       NaN            NaN  2018_19
# 163302     5.0       NaN            NaN  2018_19
# 163303     3.0       NaN            NaN  2018_19
# 163304     2.0       NaN            NaN  2018_19
# 163305     6.0       NaN            NaN  2018_19
# 163306     6.0       NaN         6904.0  2018_19
# 163307     6.0       NaN            NaN  2018_19
# 163308     6.0       NaN            NaN  2018_19
# 163309     6.0       NaN            NaN  2018_19
# 163310     6.0       NaN            NaN  2018_19
# 163311     3.0       NaN            NaN  2018_19
# 163312     2.0       NaN            NaN  2018_19
# 163313     8.0       NaN            NaN  2018_19
# 163314     8.0       NaN            NaN  2018_19
# 163315     5.0       NaN         6120.0  2018_19
# 163316     5.0       NaN         6120.0  2018_19
# 163317     5.0       NaN         5760.0  2018_19
# 163318     5.0       NaN         5940.0  2018_19
# 163319     5.0       NaN         6120.0  2018_19
# 163320     5.0       NaN         5940.0  2018_19
# 163321     5.0       NaN         6120.0  2018_19
# 163322     5.0       NaN         6120.0  2018_19
# 163323     5.0       NaN         6120.0  2018_19
# 163324     5.0       NaN         6120.0  2018_19
# 163325     5.0       NaN         6120.0  2018_19
# 163326     5.0       NaN         6120.0  2018_19
# 163327     5.0       NaN         6120.0  2018_19
# 163328     5.0       NaN            NaN  2018_19
# 163329     5.0       NaN        21420.0  2018_19
# 163330     8.0       NaN            NaN  2018_19
#
# [163331 rows x 7 columns]

# %%
df.head()
# Out:
#    UNITID                                  INSTNM STABBR  REGION  ADM_RATE  \
# 0  100636      Community College of the Air Force     AL     0.0       NaN
# 1  100654                Alabama A & M University     AL     5.0       NaN
# 2  100663     University of Alabama at Birmingham     AL     5.0       NaN
# 3  100672  ALABAMA AVIATION AND TECHNICAL COLLEGE     AL     5.0       NaN
# 4  100690                      Amridge University     AL     5.0       NaN
#
#    TUITIONFEE_IN     YEAR
# 0            NaN  1996_97
# 1            NaN  1996_97
# 2            NaN  1996_97
# 3            NaN  1996_97
# 4            NaN  1996_97

# %%
df.tail()
# Out:
#           UNITID                                    INSTNM STABBR  REGION  \
# 163326  48511112         Georgia Military College - Dublin     GA     5.0
# 163327  48511113        Georgia Military College - Eastman     GA     5.0
# 163328  48616901  American College of Barbering - Florence     KY     5.0
# 163329  49005401      HCI College - Fort Lauderdale Campus     FL     5.0
# 163330  49146401          ABC Adult School - Cabrillo Lane     CA     8.0
#
#         ADM_RATE  TUITIONFEE_IN     YEAR
# 163326       NaN         6120.0  2018_19
# 163327       NaN         6120.0  2018_19
# 163328       NaN            NaN  2018_19
# 163329       NaN        21420.0  2018_19
# 163330       NaN            NaN  2018_19

# %%
df.sample(5)
# Out:
#         UNITID                                          INSTNM STABBR  REGION  \
# 4579    218478            KENNETH SHULER SCHOOL OF COSMETOLOGY     SC     5.0
# 115221  237312                        University of Charleston     WV     5.0
# 63585   195128                               The Sage Colleges     NY     2.0
# 101438  437103                   Baton Rouge Community College     LA     5.0
# 141062  468006  South University-Accelerated Graduate Programs     GA     5.0
#
#         ADM_RATE  TUITIONFEE_IN     YEAR
# 4579         NaN            NaN  1996_97
# 115221    0.5600        19681.0  2012_13
# 63585     0.8147        23520.0  2005_06
# 101438       NaN         2474.0  2010_11
# 141062       NaN            NaN  2015_16

# %%
df.isnull().sum()
# Out:
# UNITID                0
# INSTNM                0
# STABBR                0
# REGION                1
# ADM_RATE         118420
# TUITIONFEE_IN     84137
# YEAR                  0
# dtype: int64

# %%
df.dtypes
# Out:
# UNITID             int64
# INSTNM            object
# STABBR            object
# REGION           float64
# ADM_RATE         float64
# TUITIONFEE_IN    float64
# YEAR              object
# dtype: object

# %%
df.describe()
# Out:
#              UNITID         REGION      ADM_RATE  TUITIONFEE_IN
# count  1.633310e+05  163330.000000  44911.000000   79194.000000
# mean   9.432395e+05       4.554693      0.692946   11665.505367
# std    4.571721e+06       2.189217      0.217062    9985.998016
# min    1.006360e+05       0.000000      0.000000       0.000000
# 25%    1.633380e+05       3.000000      0.555000    3776.000000
# 50%    2.127800e+05       5.000000      0.717500    9285.000000
# 75%    4.075680e+05       6.000000      0.857100   16146.000000
# max    4.914640e+07       9.000000      1.000000   74787.000000

# %%
df['YEAR'] = df['YEAR'].replace(['1996_97'],['1996'])
df['YEAR'] = df['YEAR'].replace(['1997_98'],['1997'])
df['YEAR'] = df['YEAR'].replace(['1998_99'],['1998'])
df['YEAR'] = df['YEAR'].replace(['1999_00'],['1999'])
df['YEAR'] = df['YEAR'].replace(['2000_01'],['2000'])
df['YEAR'] = df['YEAR'].replace(['2001_02'],['2001'])
df['YEAR'] = df['YEAR'].replace(['2002_03'],['2002'])
df['YEAR'] = df['YEAR'].replace(['2003_04'],['2003'])
df['YEAR'] = df['YEAR'].replace(['2004_05'],['2004'])
df['YEAR'] = df['YEAR'].replace(['2005_06'],['2005'])
df['YEAR'] = df['YEAR'].replace(['2006_07'],['2006'])
df['YEAR'] = df['YEAR'].replace(['2007_08'],['2007'])
df['YEAR'] = df['YEAR'].replace(['2008_09'],['2008'])
df['YEAR'] = df['YEAR'].replace(['2009_10'],['2009'])
df['YEAR'] = df['YEAR'].replace(['2010_11'],['2010'])
df['YEAR'] = df['YEAR'].replace(['2011_12'],['2011'])
df['YEAR'] = df['YEAR'].replace(['2012_13'],['2012'])
df['YEAR'] = df['YEAR'].replace(['2013_14'],['2013'])
df['YEAR'] = df['YEAR'].replace(['2014_15'],['2014'])
df['YEAR'] = df['YEAR'].replace(['2015_16'],['2015'])
df['YEAR'] = df['YEAR'].replace(['2016_17'],['2016'])
df['YEAR'] = df['YEAR'].replace(['2017_18'],['2017'])
df['YEAR'] = df['YEAR'].replace(['2018_19'],['2018'])

# %%
df['YEAR'] = df['YEAR'].apply(np.int64)
df
# Out:
#           UNITID                                             INSTNM STABBR  \
# 0         100636                 Community College of the Air Force     AL
# 1         100654                           Alabama A & M University     AL
# 2         100663                University of Alabama at Birmingham     AL
# 3         100672             ALABAMA AVIATION AND TECHNICAL COLLEGE     AL
# 4         100690                                 Amridge University     AL
# 5         100706                University of Alabama in Huntsville     AL
# 6         100724                           Alabama State University     AL
# 7         100751                          The University of Alabama     AL
# 8         100760                  Central Alabama Community College     AL
# 9         100812                            Athens State University     AL
# 10        100830                    Auburn University at Montgomery     AL
# 11        100858                                  Auburn University     AL
# 12        100919     Lawson State Community College-Bessemer Campus     AL
# 13        100937                        Birmingham-Southern College     AL
# 14        100964       BEVILL STATE COMMUNITY COLLEGE-BREWER CAMPUS     AL
# 15        101019                  CHARLES ACADEMY OF BEAUTY CULTURE     AL
# 16        101028             Chattahoochee Valley Community College     AL
# 17        101037            CHAUNCEY SPARKS STATE TECHNICAL COLLEGE     AL
# 18        101073                          Concordia College Alabama     AL
# 19        101107  LURLEEN B WALLACE COMMUNITY COLLEGE-MACARTHUR ...     AL
# 20        101116                        South University-Montgomery     AL
# 21        101143                 Enterprise State Community College     AL
# 22        101161                  Coastal Alabama Community College     AL
# 23        101189                                Faulkner University     AL
# 24        101198                     FAULKNER UNIVERSITY-BIRMINGHAM     AL
# 25        101204                       FAULKNER UNIVERSITY-FLORENCE     AL
# 26        101213                                FAULKNER UNIVERSITY     AL
# 27        101231                           Gadsden Business College     AL
# 28        101240                    Gadsden State Community College     AL
# 29        101268                  GADSDEN BUSINESS COLLEGE-ANNISTON     AL
# ...          ...                                                ...    ...
# 163301  48133101             Sharp Edgez Barber Institute - Buffalo     NY
# 163302  48137701            Grace College of Barbering - Greensboro     NC
# 163303  48154401  National Personal Training Institute of Cleveland     OH
# 163304  48305401             Barber School of Pittsburgh - Ambridge     PA
# 163305  48312401                 Arizona State University at Tucson     AZ
# 163306  48312402  Arizona State University - ASU Colleges at Lak...     AZ
# 163307  48312403        Arizona State University at The Gila Valley     AZ
# 163308  48312404                   Arizona State University at Yuma     AZ
# 163309  48312405                   Arizona State University - Pinal     AZ
# 163310  48312406                 Arizona State University - Cochise     AZ
# 163311  48379901       East-West Healing Arts Institute - Milwaukee     WI
# 163312  48385001                 Alliance Computing Solutions - NYC     NY
# 163313  48387801  Bay Area Medical Academy - San Jose Satellite ...     CA
# 163314  48400201           High Desert Medical College - Bakerfield     CA
# 163315  48511101                 Georgia Military College - Zebulon     GA
# 163316  48511102                  Georgia Military College - Albany     GA
# 163317  48511103                Georgia Military College - Valdosta     GA
# 163318  48511104                 Georgia Military College - Augusta     GA
# 163319  48511105                Georgia Military College - Fairburn     GA
# 163320  48511106                  Georgia Military College - Robins     GA
# 163321  48511107                Georgia Military College - Columbus     GA
# 163322  48511108            Georgia Military College - Sandersville     GA
# 163323  48511109                 Georgia Military College - Madison     GA
# 163324  48511110          Georgia Military College - Stone Mountain     GA
# 163325  48511111            Georgia Military College - Fayetteville     GA
# 163326  48511112                  Georgia Military College - Dublin     GA
# 163327  48511113                 Georgia Military College - Eastman     GA
# 163328  48616901           American College of Barbering - Florence     KY
# 163329  49005401               HCI College - Fort Lauderdale Campus     FL
# 163330  49146401                   ABC Adult School - Cabrillo Lane     CA
#
#         REGION  ADM_RATE  TUITIONFEE_IN  YEAR
# 0          0.0       NaN            NaN  1996
# 1          5.0       NaN            NaN  1996
# 2          5.0       NaN            NaN  1996
# 3          5.0       NaN            NaN  1996
# 4          5.0       NaN            NaN  1996
# 5          5.0       NaN            NaN  1996
# 6          5.0       NaN            NaN  1996
# 7          5.0       NaN            NaN  1996
# 8          5.0       NaN            NaN  1996
# 9          5.0       NaN            NaN  1996
# 10         5.0       NaN            NaN  1996
# 11         5.0       NaN            NaN  1996
# 12         5.0       NaN            NaN  1996
# 13         5.0       NaN            NaN  1996
# 14         5.0       NaN            NaN  1996
# 15         5.0       NaN            NaN  1996
# 16         5.0       NaN            NaN  1996
# 17         5.0       NaN            NaN  1996
# 18         5.0       NaN            NaN  1996
# 19         5.0       NaN            NaN  1996
# 20         5.0       NaN            NaN  1996
# 21         5.0       NaN            NaN  1996
# 22         5.0       NaN            NaN  1996
# 23         5.0       NaN            NaN  1996
# 24         5.0       NaN            NaN  1996
# 25         5.0       NaN            NaN  1996
# 26         5.0       NaN            NaN  1996
# 27         5.0       NaN            NaN  1996
# 28         5.0       NaN            NaN  1996
# 29         5.0       NaN            NaN  1996
# ...        ...       ...            ...   ...
# 163301     2.0       NaN            NaN  2018
# 163302     5.0       NaN            NaN  2018
# 163303     3.0       NaN            NaN  2018
# 163304     2.0       NaN            NaN  2018
# 163305     6.0       NaN            NaN  2018
# 163306     6.0       NaN         6904.0  2018
# 163307     6.0       NaN            NaN  2018
# 163308     6.0       NaN            NaN  2018
# 163309     6.0       NaN            NaN  2018
# 163310     6.0       NaN            NaN  2018
# 163311     3.0       NaN            NaN  2018
# 163312     2.0       NaN            NaN  2018
# 163313     8.0       NaN            NaN  2018
# 163314     8.0       NaN            NaN  2018
# 163315     5.0       NaN         6120.0  2018
# 163316     5.0       NaN         6120.0  2018
# 163317     5.0       NaN         5760.0  2018
# 163318     5.0       NaN         5940.0  2018
# 163319     5.0       NaN         6120.0  2018
# 163320     5.0       NaN         5940.0  2018
# 163321     5.0       NaN         6120.0  2018
# 163322     5.0       NaN         6120.0  2018
# 163323     5.0       NaN         6120.0  2018
# 163324     5.0       NaN         6120.0  2018
# 163325     5.0       NaN         6120.0  2018
# 163326     5.0       NaN         6120.0  2018
# 163327     5.0       NaN         6120.0  2018
# 163328     5.0       NaN            NaN  2018
# 163329     5.0       NaN        21420.0  2018
# 163330     8.0       NaN            NaN  2018
#
# [163331 rows x 7 columns]

# %% [markdown]
# 7. Filter/query the dataframe to retrieve only rows that belong to UMBC

# %%
UMBCdf=df[df['INSTNM']=='University of Maryland-Baltimore County']
UMBCdf
# Out:
#         UNITID                                   INSTNM STABBR  REGION  \
# 2151    163268  University of Maryland-Baltimore County     MD     2.0
# 9056    163268  University of Maryland-Baltimore County     MD     2.0
# 15923   163268  University of Maryland-Baltimore County     MD     2.0
# 22598   163268  University of Maryland-Baltimore County     MD     2.0
# 29178   163268  University of Maryland-Baltimore County     MD     2.0
# 35821   163268  University of Maryland-Baltimore County     MD     2.0
# 42524   163268  University of Maryland-Baltimore County     MD     2.0
# 49156   163268  University of Maryland-Baltimore County     MD     2.0
# 55786   163268  University of Maryland-Baltimore County     MD     2.0
# 62522   163268  University of Maryland-Baltimore County     MD     2.0
# 69401   163268  University of Maryland-Baltimore County     MD     2.0
# 76332   163268  University of Maryland-Baltimore County     MD     2.0
# 83291   163268  University of Maryland-Baltimore County     MD     2.0
# 90324   163268  University of Maryland-Baltimore County     MD     2.0
# 97506   163268  University of Maryland-Baltimore County     MD     2.0
# 104960  163268  University of Maryland-Baltimore County     MD     2.0
# 112672  163268  University of Maryland-Baltimore County     MD     2.0
# 120503  163268  University of Maryland-Baltimore County     MD     2.0
# 128353  163268  University of Maryland-Baltimore County     MD     2.0
# 136064  163268  University of Maryland-Baltimore County     MD     2.0
# 143685  163268  University of Maryland-Baltimore County     MD     2.0
# 150891  163268  University of Maryland-Baltimore County     MD     2.0
# 157940  163268  University of Maryland-Baltimore County     MD     2.0
#
#         ADM_RATE  TUITIONFEE_IN  YEAR
# 2151         NaN            NaN  1996
# 9056         NaN            NaN  1997
# 15923        NaN            NaN  1998
# 22598        NaN            NaN  1999
# 29178        NaN         5490.0  2000
# 35821     0.6551         5910.0  2001
# 42524     0.6327         6362.0  2002
# 49156     0.5757         7388.0  2003
# 55786     0.7014         8020.0  2004
# 62522     0.7143         8520.0  2005
# 69401     0.7153         8622.0  2006
# 76332     0.6895         8708.0  2007
# 83291     0.7174         8780.0  2008
# 90324     0.6890         8872.0  2009
# 97506     0.6589         9171.0  2010
# 104960    0.6081         9467.0  2011
# 112672    0.6035         9764.0  2012
# 120503    0.6315        10068.0  2013
# 128353    0.5961        10384.0  2014
# 136064    0.5942        11006.0  2015
# 143685    0.5683        11264.0  2016
# 150891    0.6021        11518.0  2017
# 157940    0.5794        11778.0  2018

# %% [markdown]
# 8. Explore this UMBC dataframe (# of observations, varibles, head, tail, sample, missing values, statistics,etc.)

# %%
type(UMBCdf)
# Out:
# pandas.core.frame.DataFrame

# %%
UMBCdf.head()
# Out:
#        UNITID                                   INSTNM STABBR  REGION  \
# 2151   163268  University of Maryland-Baltimore County     MD     2.0
# 9056   163268  University of Maryland-Baltimore County     MD     2.0
# 15923  163268  University of Maryland-Baltimore County     MD     2.0
# 22598  163268  University of Maryland-Baltimore County     MD     2.0
# 29178  163268  University of Maryland-Baltimore County     MD     2.0
#
#        ADM_RATE  TUITIONFEE_IN  YEAR
# 2151        NaN            NaN  1996
# 9056        NaN            NaN  1997
# 15923       NaN            NaN  1998
# 22598       NaN            NaN  1999
# 29178       NaN         5490.0  2000

# %%
UMBCdf.tail()
# Out:
#         UNITID                                   INSTNM STABBR  REGION  \
# 128353  163268  University of Maryland-Baltimore County     MD     2.0
# 136064  163268  University of Maryland-Baltimore County     MD     2.0
# 143685  163268  University of Maryland-Baltimore County     MD     2.0
# 150891  163268  University of Maryland-Baltimore County     MD     2.0
# 157940  163268  University of Maryland-Baltimore County     MD     2.0
#
#         ADM_RATE  TUITIONFEE_IN  YEAR
# 128353    0.5961        10384.0  2014
# 136064    0.5942        11006.0  2015
# 143685    0.5683        11264.0  2016
# 150891    0.6021        11518.0  2017
# 157940    0.5794        11778.0  2018

# %%
UMBCdf.sample(5)
# Out:
#         UNITID                                   INSTNM STABBR  REGION  \
# 97506   163268  University of Maryland-Baltimore County     MD     2.0
# 83291   163268  University of Maryland-Baltimore County     MD     2.0
# 90324   163268  University of Maryland-Baltimore County     MD     2.0
# 112672  163268  University of Maryland-Baltimore County     MD     2.0
# 35821   163268  University of Maryland-Baltimore County     MD     2.0
#
#         ADM_RATE  TUITIONFEE_IN  YEAR
# 97506     0.6589         9171.0  2010
# 83291     0.7174         8780.0  2008
# 90324     0.6890         8872.0  2009
# 112672    0.6035         9764.0  2012
# 35821     0.6551         5910.0  2001

# %%
UMBCdf.isnull().sum()
# Out:
# UNITID           0
# INSTNM           0
# STABBR           0
# REGION           0
# ADM_RATE         5
# TUITIONFEE_IN    4
# YEAR             0
# dtype: int64

# %%
UMBCdf.dtypes
# Out:
# UNITID             int64
# INSTNM            object
# STABBR            object
# REGION           float64
# ADM_RATE         float64
# TUITIONFEE_IN    float64
# YEAR               int64
# dtype: object

# %%
UMBCdf.describe()
# Out:
#          UNITID  REGION   ADM_RATE  TUITIONFEE_IN        YEAR
# count      23.0    23.0  18.000000      19.000000    23.00000
# mean   163268.0     2.0   0.640694    9004.842105  2007.00000
# std         0.0     0.0   0.052728    1825.795421     6.78233
# min    163268.0     2.0   0.568300    5490.000000  1996.00000
# 25%    163268.0     2.0   0.597600    8270.000000  2001.50000
# 50%    163268.0     2.0   0.632100    8872.000000  2007.00000
# 75%    163268.0     2.0   0.689375   10226.000000  2012.50000
# max    163268.0     2.0   0.717400   11778.000000  2018.00000

# %% [markdown]
# 9. Plot UMBC's in-state tution overtime from 1996 to 2019 using Bar Chart

# %%
UMBCdf.plot(x="YEAR", y="TUITIONFEE_IN", kind="bar")

# %% [markdown]
# 10. Plot UMBC's in-state tution overtime from 1996 to 2019 using Line Chart

# %%
UMBCdf.plot(x="YEAR", y="TUITIONFEE_IN")
plt.show()

# %% [markdown]
# 11. UMBC tuition change percentage each year

# %% [markdown]
# a. Using as a list

# %%
#https://thispointer.com/pandas-convert-a-dataframe-column-into-a-list-using-series-to_list-or-numpy-ndarray-tolist-in-python/
tuitionfee = UMBCdf['TUITIONFEE_IN'].to_list()

# %%
#https://stackoverflow.com/questions/12700166/calculating-change-in-percentage-between-two-numbers-python
for a, b in zip(tuitionfee[::1], tuitionfee[1::1]):
    print(100 * (b - a) / a)
# Out:
# nan
# nan
# nan
# nan
# 7.6502732240437155
# 7.648054145516075
# 16.12700408676517
# 8.554412560909583
# 6.234413965087282
# 1.1971830985915493
# 0.9974483878450475
# 0.8268259072117593
# 1.0478359908883828
# 3.3701532912533816
# 3.227565151019518
# 3.137213478398648
# 3.11347808275297
# 3.1386571315057608
# 5.989984591679507
# 2.344175904052335
# 2.254971590909091
# 2.2573363431151243

# %% [markdown]
# b. Using pandas

# %%
#https://stackoverflow.com/questions/12700166/calculating-change-in-percentage-between-two-numbers-python

price_series = pd.Series(UMBCdf['TUITIONFEE_IN'])
pctchange = price_series.pct_change() * 100

# %%
pctchange
# Out:
# 2151            NaN
# 9056            NaN
# 15923           NaN
# 22598           NaN
# 29178           NaN
# 35821      7.650273
# 42524      7.648054
# 49156     16.127004
# 55786      8.554413
# 62522      6.234414
# 69401      1.197183
# 76332      0.997448
# 83291      0.826826
# 90324      1.047836
# 97506      3.370153
# 104960     3.227565
# 112672     3.137213
# 120503     3.113478
# 128353     3.138657
# 136064     5.989985
# 143685     2.344176
# 150891     2.254972
# 157940     2.257336
# Name: TUITIONFEE_IN, dtype: float64

# %% [markdown]
# Add the list of the percentages to the dataframe as a new column ("PCT_CHANGE")

# %%
UMBCdf['PCT_CHANGE'] = pctchange
# Out:
# C:\Users\shrut\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
UMBCdf
# Out:
#         UNITID                                   INSTNM STABBR  REGION  \
# 2151    163268  University of Maryland-Baltimore County     MD     2.0
# 9056    163268  University of Maryland-Baltimore County     MD     2.0
# 15923   163268  University of Maryland-Baltimore County     MD     2.0
# 22598   163268  University of Maryland-Baltimore County     MD     2.0
# 29178   163268  University of Maryland-Baltimore County     MD     2.0
# 35821   163268  University of Maryland-Baltimore County     MD     2.0
# 42524   163268  University of Maryland-Baltimore County     MD     2.0
# 49156   163268  University of Maryland-Baltimore County     MD     2.0
# 55786   163268  University of Maryland-Baltimore County     MD     2.0
# 62522   163268  University of Maryland-Baltimore County     MD     2.0
# 69401   163268  University of Maryland-Baltimore County     MD     2.0
# 76332   163268  University of Maryland-Baltimore County     MD     2.0
# 83291   163268  University of Maryland-Baltimore County     MD     2.0
# 90324   163268  University of Maryland-Baltimore County     MD     2.0
# 97506   163268  University of Maryland-Baltimore County     MD     2.0
# 104960  163268  University of Maryland-Baltimore County     MD     2.0
# 112672  163268  University of Maryland-Baltimore County     MD     2.0
# 120503  163268  University of Maryland-Baltimore County     MD     2.0
# 128353  163268  University of Maryland-Baltimore County     MD     2.0
# 136064  163268  University of Maryland-Baltimore County     MD     2.0
# 143685  163268  University of Maryland-Baltimore County     MD     2.0
# 150891  163268  University of Maryland-Baltimore County     MD     2.0
# 157940  163268  University of Maryland-Baltimore County     MD     2.0
#
#         ADM_RATE  TUITIONFEE_IN  YEAR  PCT_CHANGE
# 2151         NaN            NaN  1996         NaN
# 9056         NaN            NaN  1997         NaN
# 15923        NaN            NaN  1998         NaN
# 22598        NaN            NaN  1999         NaN
# 29178        NaN         5490.0  2000         NaN
# 35821     0.6551         5910.0  2001    7.650273
# 42524     0.6327         6362.0  2002    7.648054
# 49156     0.5757         7388.0  2003   16.127004
# 55786     0.7014         8020.0  2004    8.554413
# 62522     0.7143         8520.0  2005    6.234414
# 69401     0.7153         8622.0  2006    1.197183
# 76332     0.6895         8708.0  2007    0.997448
# 83291     0.7174         8780.0  2008    0.826826
# 90324     0.6890         8872.0  2009    1.047836
# 97506     0.6589         9171.0  2010    3.370153
# 104960    0.6081         9467.0  2011    3.227565
# 112672    0.6035         9764.0  2012    3.137213
# 120503    0.6315        10068.0  2013    3.113478
# 128353    0.5961        10384.0  2014    3.138657
# 136064    0.5942        11006.0  2015    5.989985
# 143685    0.5683        11264.0  2016    2.344176
# 150891    0.6021        11518.0  2017    2.254972
# 157940    0.5794        11778.0  2018    2.257336

# %%
UMBCdf['PCT_CHANGE'] = UMBCdf['PCT_CHANGE'].round(2)
# Out:
# C:\Users\shrut\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
UMBCdf.tail()
# Out:
#         UNITID                                   INSTNM STABBR  REGION  \
# 128353  163268  University of Maryland-Baltimore County     MD     2.0
# 136064  163268  University of Maryland-Baltimore County     MD     2.0
# 143685  163268  University of Maryland-Baltimore County     MD     2.0
# 150891  163268  University of Maryland-Baltimore County     MD     2.0
# 157940  163268  University of Maryland-Baltimore County     MD     2.0
#
#         ADM_RATE  TUITIONFEE_IN  YEAR  PCT_CHANGE
# 128353    0.5961        10384.0  2014        3.14
# 136064    0.5942        11006.0  2015        5.99
# 143685    0.5683        11264.0  2016        2.34
# 150891    0.6021        11518.0  2017        2.25
# 157940    0.5794        11778.0  2018        2.26

# %% [markdown]
# 12. Plot tuition growth rate year over year - bar first, then line chart

# %%
UMBCdf.plot(x="YEAR", y="PCT_CHANGE", kind="bar")

# %%
UMBCdf.plot(x="YEAR", y="PCT_CHANGE")
plt.show()

# %%
price_series1 = pd.Series(df['TUITIONFEE_IN'])
pctchangemain = price_series1.pct_change() * 100

# %%
pctchangemain
# Out:
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15               NaN
# 16               NaN
# 17               NaN
# 18               NaN
# 19               NaN
# 20               NaN
# 21               NaN
# 22               NaN
# 23               NaN
# 24               NaN
# 25               NaN
# 26               NaN
# 27               NaN
# 28               NaN
# 29               NaN
#              ...
# 163301      0.000000
# 163302      0.000000
# 163303      0.000000
# 163304      0.000000
# 163305      0.000000
# 163306    -36.863283
# 163307      0.000000
# 163308      0.000000
# 163309      0.000000
# 163310      0.000000
# 163311      0.000000
# 163312      0.000000
# 163313      0.000000
# 163314      0.000000
# 163315    -11.355736
# 163316      0.000000
# 163317     -5.882353
# 163318      3.125000
# 163319      3.030303
# 163320     -2.941176
# 163321      3.030303
# 163322      0.000000
# 163323      0.000000
# 163324      0.000000
# 163325      0.000000
# 163326      0.000000
# 163327      0.000000
# 163328      0.000000
# 163329    250.000000
# 163330      0.000000
# Name: TUITIONFEE_IN, Length: 163331, dtype: float64

# %% [markdown]
# 13. Filter/query the dataframe to retrieve only rows that belong to JHU

# %%
JHUdf=df[df['INSTNM']=='Johns Hopkins University']
JHUdf
# Out:
#         UNITID                    INSTNM STABBR  REGION  ADM_RATE  \
# 2139    162928  Johns Hopkins University     MD     2.0       NaN
# 9046    162928  Johns Hopkins University     MD     2.0       NaN
# 15914   162928  Johns Hopkins University     MD     2.0       NaN
# 22589   162928  Johns Hopkins University     MD     2.0       NaN
# 29169   162928  Johns Hopkins University     MD     2.0       NaN
# 35812   162928  Johns Hopkins University     MD     2.0    0.3431
# 42515   162928  Johns Hopkins University     MD     2.0    0.3506
# 49148   162928  Johns Hopkins University     MD     2.0    0.3060
# 55779   162928  Johns Hopkins University     MD     2.0    0.3071
# 62515   162928  Johns Hopkins University     MD     2.0    0.3509
# 69394   162928  Johns Hopkins University     MD     2.0    0.2792
# 76325   162928  Johns Hopkins University     MD     2.0    0.2571
# 83284   162928  Johns Hopkins University     MD     2.0    0.2609
# 90317   162928  Johns Hopkins University     MD     2.0    0.2782
# 97499   162928  Johns Hopkins University     MD     2.0    0.2225
# 104953  162928  Johns Hopkins University     MD     2.0    0.1940
# 112665  162928  Johns Hopkins University     MD     2.0    0.1843
# 120496  162928  Johns Hopkins University     MD     2.0    0.1813
# 128346  162928  Johns Hopkins University     MD     2.0    0.1608
# 136057  162928  Johns Hopkins University     MD     2.0    0.1412
# 143678  162928  Johns Hopkins University     MD     2.0    0.1284
# 150886  162928  Johns Hopkins University     MD     2.0    0.1254
# 157935  162928  Johns Hopkins University     MD     2.0    0.1148
#
#         TUITIONFEE_IN  YEAR
# 2139              NaN  1996
# 9046              NaN  1997
# 15914             NaN  1998
# 22589             NaN  1999
# 29169         24930.0  2000
# 35812         26210.0  2001
# 42515         27390.0  2002
# 49148         28730.0  2003
# 55779         30140.0  2004
# 62515         31620.0  2005
# 69394         33900.0  2006
# 76325         35900.0  2007
# 83284         37700.0  2008
# 90317         39150.0  2009
# 97499         40680.0  2010
# 104953        42280.0  2011
# 112665        43390.0  2012
# 120496        45470.0  2013
# 128346        47060.0  2014
# 136057        48710.0  2015
# 143678        50410.0  2016
# 150886        52170.0  2017
# 157935        53740.0  2018

# %%
JHUdf.head()
# Out:
#        UNITID                    INSTNM STABBR  REGION  ADM_RATE  \
# 2139   162928  Johns Hopkins University     MD     2.0       NaN
# 9046   162928  Johns Hopkins University     MD     2.0       NaN
# 15914  162928  Johns Hopkins University     MD     2.0       NaN
# 22589  162928  Johns Hopkins University     MD     2.0       NaN
# 29169  162928  Johns Hopkins University     MD     2.0       NaN
#
#        TUITIONFEE_IN  YEAR
# 2139             NaN  1996
# 9046             NaN  1997
# 15914            NaN  1998
# 22589            NaN  1999
# 29169        24930.0  2000

# %%
JHUdf.tail()
# Out:
#         UNITID                    INSTNM STABBR  REGION  ADM_RATE  \
# 128346  162928  Johns Hopkins University     MD     2.0    0.1608
# 136057  162928  Johns Hopkins University     MD     2.0    0.1412
# 143678  162928  Johns Hopkins University     MD     2.0    0.1284
# 150886  162928  Johns Hopkins University     MD     2.0    0.1254
# 157935  162928  Johns Hopkins University     MD     2.0    0.1148
#
#         TUITIONFEE_IN  YEAR
# 128346        47060.0  2014
# 136057        48710.0  2015
# 143678        50410.0  2016
# 150886        52170.0  2017
# 157935        53740.0  2018

# %%
JHUdf.sample(5)
# Out:
#        UNITID                    INSTNM STABBR  REGION  ADM_RATE  \
# 2139   162928  Johns Hopkins University     MD     2.0       NaN
# 15914  162928  Johns Hopkins University     MD     2.0       NaN
# 9046   162928  Johns Hopkins University     MD     2.0       NaN
# 49148  162928  Johns Hopkins University     MD     2.0    0.3060
# 90317  162928  Johns Hopkins University     MD     2.0    0.2782
#
#        TUITIONFEE_IN  YEAR
# 2139             NaN  1996
# 15914            NaN  1998
# 9046             NaN  1997
# 49148        28730.0  2003
# 90317        39150.0  2009

# %%
JHUdf.isnull().sum()
# Out:
# UNITID           0
# INSTNM           0
# STABBR           0
# REGION           0
# ADM_RATE         5
# TUITIONFEE_IN    4
# YEAR             0
# dtype: int64

# %%
JHUdf.describe()
# Out:
#          UNITID  REGION   ADM_RATE  TUITIONFEE_IN        YEAR
# count      23.0    23.0  18.000000      19.000000    23.00000
# mean   162928.0     2.0   0.232544   38925.263158  2007.00000
# std         0.0     0.0   0.081533    9210.110609     6.78233
# min    162928.0     2.0   0.114800   24930.000000  1996.00000
# 25%    162928.0     2.0   0.165925   30880.000000  2001.50000
# 50%    162928.0     2.0   0.239800   39150.000000  2007.00000
# 75%    162928.0     2.0   0.299300   46265.000000  2012.50000
# max    162928.0     2.0   0.350900   53740.000000  2018.00000

# %% [markdown]
# 14. Plot JHU's in-state tuition overtime from 1996 to 2019.

# %%
JHUdf.plot(x="YEAR", y="TUITIONFEE_IN", kind="bar")

# %%
JHUdf.plot(x="YEAR", y="TUITIONFEE_IN")
plt.show()

# %% [markdown]
# 15. calculate the JHU tuition percentge growth

# %%
price_seriesjhu = pd.Series(JHUdf['TUITIONFEE_IN'])
pctchangejhu = price_seriesjhu.pct_change() * 100

# %%
pctchangejhu
# Out:
# 2139           NaN
# 9046           NaN
# 15914          NaN
# 22589          NaN
# 29169          NaN
# 35812     5.134376
# 42515     4.502098
# 49148     4.892296
# 55779     4.907762
# 62515     4.910418
# 69394     7.210626
# 76325     5.899705
# 83284     5.013928
# 90317     3.846154
# 97499     3.908046
# 104953    3.933137
# 112665    2.625355
# 120496    4.793731
# 128346    3.496811
# 136057    3.506162
# 143678    3.490043
# 150886    3.491371
# 157935    3.009392
# Name: TUITIONFEE_IN, dtype: float64

# %% [markdown]
# 16. Add the list of percentage changes to the dataframe as a new column ("PCT_CHANGE")

# %%
JHUdf['PCT_CHANGE'] = pctchangejhu
# Out:
# C:\Users\shrut\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
JHUdf.tail()
# Out:
#         UNITID                    INSTNM STABBR  REGION  ADM_RATE  \
# 128346  162928  Johns Hopkins University     MD     2.0    0.1608
# 136057  162928  Johns Hopkins University     MD     2.0    0.1412
# 143678  162928  Johns Hopkins University     MD     2.0    0.1284
# 150886  162928  Johns Hopkins University     MD     2.0    0.1254
# 157935  162928  Johns Hopkins University     MD     2.0    0.1148
#
#         TUITIONFEE_IN  YEAR  PCT_CHANGE
# 128346        47060.0  2014    3.496811
# 136057        48710.0  2015    3.506162
# 143678        50410.0  2016    3.490043
# 150886        52170.0  2017    3.491371
# 157935        53740.0  2018    3.009392

# %%
JHUdf['PCT_CHANGE'] = JHUdf['PCT_CHANGE'].round(2)
# Out:
# C:\Users\shrut\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
JHUdf.tail()
# Out:
#         UNITID                    INSTNM STABBR  REGION  ADM_RATE  \
# 128346  162928  Johns Hopkins University     MD     2.0    0.1608
# 136057  162928  Johns Hopkins University     MD     2.0    0.1412
# 143678  162928  Johns Hopkins University     MD     2.0    0.1284
# 150886  162928  Johns Hopkins University     MD     2.0    0.1254
# 157935  162928  Johns Hopkins University     MD     2.0    0.1148
#
#         TUITIONFEE_IN  YEAR  PCT_CHANGE
# 128346        47060.0  2014        3.50
# 136057        48710.0  2015        3.51
# 143678        50410.0  2016        3.49
# 150886        52170.0  2017        3.49
# 157935        53740.0  2018        3.01

# %% [markdown]
# 17. Make a bar plot of the JHU percentage changes tuitions over time

# %%
JHUdf.plot(x="YEAR", y="PCT_CHANGE", kind="bar")

# %%
JHUdf.plot(x="YEAR", y="PCT_CHANGE")
plt.show()

# %% [markdown]
# 18. combine the two datasets using the common key of YEAR

# %%
umbc2 = UMBCdf.filter(['YEAR', 'PCT_CHANGE'])
umbc2
# Out:
#         YEAR  PCT_CHANGE
# 2151    1996         NaN
# 9056    1997         NaN
# 15923   1998         NaN
# 22598   1999         NaN
# 29178   2000         NaN
# 35821   2001        7.65
# 42524   2002        7.65
# 49156   2003       16.13
# 55786   2004        8.55
# 62522   2005        6.23
# 69401   2006        1.20
# 76332   2007        1.00
# 83291   2008        0.83
# 90324   2009        1.05
# 97506   2010        3.37
# 104960  2011        3.23
# 112672  2012        3.14
# 120503  2013        3.11
# 128353  2014        3.14
# 136064  2015        5.99
# 143685  2016        2.34
# 150891  2017        2.25
# 157940  2018        2.26

# %%
type(umbc2)
# Out:
# pandas.core.frame.DataFrame

# %%
jhu2 = JHUdf.filter(['YEAR', 'PCT_CHANGE'])
jhu2
# Out:
#         YEAR  PCT_CHANGE
# 2139    1996         NaN
# 9046    1997         NaN
# 15914   1998         NaN
# 22589   1999         NaN
# 29169   2000         NaN
# 35812   2001        5.13
# 42515   2002        4.50
# 49148   2003        4.89
# 55779   2004        4.91
# 62515   2005        4.91
# 69394   2006        7.21
# 76325   2007        5.90
# 83284   2008        5.01
# 90317   2009        3.85
# 97499   2010        3.91
# 104953  2011        3.93
# 112665  2012        2.63
# 120496  2013        4.79
# 128346  2014        3.50
# 136057  2015        3.51
# 143678  2016        3.49
# 150886  2017        3.49
# 157935  2018        3.01

# %%
#https://www.geeksforgeeks.org/how-to-rename-columns-in-pandas-dataframe/
umbc2.rename(columns = {'PCT_CHANGE':'UMBC_PCT'}, inplace = True)

# %%
umbc2
# Out:
#         YEAR  UMBC_PCT
# 2151    1996       NaN
# 9056    1997       NaN
# 15923   1998       NaN
# 22598   1999       NaN
# 29178   2000       NaN
# 35821   2001      7.65
# 42524   2002      7.65
# 49156   2003     16.13
# 55786   2004      8.55
# 62522   2005      6.23
# 69401   2006      1.20
# 76332   2007      1.00
# 83291   2008      0.83
# 90324   2009      1.05
# 97506   2010      3.37
# 104960  2011      3.23
# 112672  2012      3.14
# 120503  2013      3.11
# 128353  2014      3.14
# 136064  2015      5.99
# 143685  2016      2.34
# 150891  2017      2.25
# 157940  2018      2.26

# %%
jhu2.rename(columns = {'PCT_CHANGE':'JHU_PCT'}, inplace = True)

# %%
jhu2
# Out:
#         YEAR  JHU_PCT
# 2139    1996      NaN
# 9046    1997      NaN
# 15914   1998      NaN
# 22589   1999      NaN
# 29169   2000      NaN
# 35812   2001     5.13
# 42515   2002     4.50
# 49148   2003     4.89
# 55779   2004     4.91
# 62515   2005     4.91
# 69394   2006     7.21
# 76325   2007     5.90
# 83284   2008     5.01
# 90317   2009     3.85
# 97499   2010     3.91
# 104953  2011     3.93
# 112665  2012     2.63
# 120496  2013     4.79
# 128346  2014     3.50
# 136057  2015     3.51
# 143678  2016     3.49
# 150886  2017     3.49
# 157935  2018     3.01

# %% [markdown]
# Merge the two dataframes

# %%
#https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
result = pd.merge(umbc2, jhu2, on='YEAR')
type(result)
# Out:
# pandas.core.frame.DataFrame

# %%
result
# Out:
#     YEAR  UMBC_PCT  JHU_PCT
# 0   1996       NaN      NaN
# 1   1997       NaN      NaN
# 2   1998       NaN      NaN
# 3   1999       NaN      NaN
# 4   2000       NaN      NaN
# 5   2001      7.65     5.13
# 6   2002      7.65     4.50
# 7   2003     16.13     4.89
# 8   2004      8.55     4.91
# 9   2005      6.23     4.91
# 10  2006      1.20     7.21
# 11  2007      1.00     5.90
# 12  2008      0.83     5.01
# 13  2009      1.05     3.85
# 14  2010      3.37     3.91
# 15  2011      3.23     3.93
# 16  2012      3.14     2.63
# 17  2013      3.11     4.79
# 18  2014      3.14     3.50
# 19  2015      5.99     3.51
# 20  2016      2.34     3.49
# 21  2017      2.25     3.49
# 22  2018      2.26     3.01

# %% [markdown]
# Plot UMBC and JHU separately on the same plot

# %%
#https://stackoverflow.com/questions/42128467/matplotlib-plot-multiple-columns-of-pandas-data-frame-on-the-bar-chart
result.plot(x="YEAR", y=["UMBC_PCT", "JHU_PCT"], kind="bar")

# %%
result.plot(x="YEAR", y=["UMBC_PCT", "JHU_PCT"])
plt.show()

# %% [markdown]
# 20. document your observation/conclusion of the comparison plots (bar/line)
#
# Based on the observation of the plots, there has been drastic decrease and increase in the percentage when it comes to UMBC instate tuitionfee growth from 2002 to 2010 whereas there has been small decrease and increase in the percentage of instate tuitionfee growth of JHU.
