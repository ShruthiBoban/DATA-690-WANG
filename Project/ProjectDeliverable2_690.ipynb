# %% [markdown]
# # Project Deliverable #2
#
# **1. What is your issue of interest (provide sufficient background information)?**
#
# Renewable energy is collected from renewable resources which can be used repeatedly which leads to a positive life cycle of a human being. The goal of Historic Clean Energy Grant Program was to increase the amount of renewable energy generated in Maryland.
#
# **2. Why is this issue important to you and/or to others?**
#
# This issue is important as the increase in the usage of renewable energy leads into less global warming and improves public health and by these awards, the increase in renewable energies were possible.
#
# **3. What questions do you have in mind and would like to answer?**
#
#    Which renewable energy project has been implemented more over the years?
#
#    Whether the Award Amount increases or decreases every year?
#
#    Is there a particular areas that have more projects (# of project, and/or total spending)?
#
#
# **4. Where do you get the data to help answer your questions?**
#
# Data Source : https://opendata.maryland.gov/Energy-and-Environment/Historic-Clean-Energy-Grant-Awards/4jem-ugpy/data
#
# Data Source discovered from : https://umbc.app.box.com/notes/375877568053?s=inwbinsctcmedcknp7h8r3tm1das5vs9 . I was trying to check on data from different places like chicago, new york and maryland which finally led me to the link (https://opendata.maryland.gov/) thus ended up finding the data source.
#
# Number of Rows in the dataset : 12988 Number of columns in the dataset : 18 Data Size : 3.27MB
#
# **5. What will be your unit of analysis (for example, patient, organization, or country)? Roughly how many units do you expect to analyze?**
#
# I am planning to analyze Total Project Cost, Award Date, Technology, Award Amount. I might roughly use 4 to 5 units for analysing.
#
# **6. What variables/measures do you plan to use in your analysis?**
#
# To find out which renewable energy has got the highest project cost, I need to have the energies (Technology unit) and the total project cost. To find out if the Award Amount increases or decreases every year. I need to have Year and Award Amount.
#
# **7. What kinds of techniques do you you plan to use (for example, summary statistics, scatter plot, bar chart, chi-squared test)?**
#
# I plan to use summary statistics, histograms, bar chart. I would also like to improvise my analysis when I am actually working on it.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure #library
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Data Loading and Exploring the dataframe

# %%
#reading the excel file as csv which consists of the dataset
#citation - https://www.shanelynn.ie/using-pandas-dataframe-creating-editing-viewing-data-in-python/
df = pd.read_csv("Historic_Clean_Energy_Grant_Awards.csv",encoding = 'utf-8')
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#counting the number of rows in the dataframe
#citation - https://stackoverflow.com/questions/15943769/how-do-i-get-the-row-count-of-a-pandas-dataframe
len(df.index)
# Out:
# 12988

# %%
#counting the number of columns in the dataframe
#citation - https://stackoverflow.com/questions/15943769/how-do-i-get-the-row-count-of-a-pandas-dataframe
len(df.columns)
# Out:
# 18

# %%
#displaying the content in the dataframe
df.head()
# Out:
#                              Program Name       Technology  \
# 0  Residential Clean Energy Grant Program       Geothermal
# 1  Residential Clean Energy Grant Program       Geothermal
# 2  Residential Clean Energy Grant Program  Solar Hot Water
# 3  Residential Clean Energy Grant Program       Geothermal
# 4  Residential Clean Energy Grant Program         Solar PV
#
#   Application Received Date  Award Date Award Amount Actual Start Date  \
# 0                11/28/2014  12/09/2014     3,000.00        01/28/2014
# 1                11/18/2014  12/09/2014     3,000.00        03/26/2014
# 2                06/24/2014  12/09/2014       500.00        04/16/2014
# 3                11/11/2014  12/09/2014     3,000.00        07/09/2014
# 4                09/05/2014  12/09/2014     1,000.00        07/30/2014
#
#   Actual End Date    Award Status Last Invoice Received Date  \
# 0      04/11/2014  Award Complete                 01/07/2015
# 1      09/02/2015  Award Complete                 01/07/2015
# 2      06/12/2014  Award Complete                 01/07/2015
# 3      09/17/2014  Award Complete                 01/07/2015
# 4      08/08/2014  Award Complete                 01/07/2015
#
#   Total Disbursed Amount Capacity Capacity Units Total Project Cost  \
# 0               3,000.00      3.5            ton          17,909.00
# 1               3,000.00        4            ton          41,560.00
# 2                 500.00     64.3           sqft          50,000.00
# 3               3,000.00        5            ton          27,829.00
# 4               1,000.00     6.48             kW          22,750.00
#
#    Ownership          City  Zip Code      County  \
# 0  Purchased    North East   21901.0       Cecil
# 1  Purchased   Lutherville   21093.0   Baltimore
# 2  Purchased   Forest Hill   21050.0     Harford
# 3  Purchased        Laurel   20723.0      Howard
# 4  Purchased  Gaithersburg   20878.0  Montgomery
#
#                                             Location
# 0  North East, Maryland 21901\n(39.59943917900006...
# 1  Lutherville, Maryland 21093\n(39.4422195000000...
# 2  Forest Hill, Maryland 21050\n(39.5734864610000...
# 3  Laurel, Maryland 20723\n(39.127289156000074, -...
# 4  Gaithersburg, Maryland 20878\n(39.118316720000...

# %%
df.tail()
# Out:
#                             Program Name       Technology  \
# 12983  Hist Residential Renewable Grants  Solar Hot Water
# 12984  Hist Residential Renewable Grants  Solar Hot Water
# 12985  Hist Residential Renewable Grants  Solar Hot Water
# 12986  Hist Residential Renewable Grants  Solar Hot Water
# 12987  Hist Residential Renewable Grants  Solar Hot Water
#
#       Application Received Date  Award Date Award Amount Actual Start Date  \
# 12983                01/01/2005  01/01/2005     1,541.00               NaN
# 12984                01/01/2005  01/01/2005     1,541.00               NaN
# 12985                01/01/2005  01/01/2005     1,541.00               NaN
# 12986                01/01/2005  01/01/2005     1,541.00               NaN
# 12987                01/01/2005  01/01/2005     1,541.00               NaN
#
#       Actual End Date    Award Status Last Invoice Received Date  \
# 12983      01/01/2005  Award Complete                        NaN
# 12984      01/01/2005  Award Complete                        NaN
# 12985      01/01/2005  Award Complete                        NaN
# 12986      01/01/2005  Award Complete                        NaN
# 12987      01/01/2005  Award Complete                        NaN
#
#       Total Disbursed Amount Capacity Capacity Units Total Project Cost  \
# 12983                   0.00       50           sqft           9,568.00
# 12984                   0.00       50           sqft           9,568.00
# 12985                   0.00       50           sqft           9,568.00
# 12986                   0.00       50           sqft           9,568.00
# 12987                   0.00       50           sqft           9,568.00
#
#        Ownership       City  Zip Code        County  \
# 12983  Purchased  Annapolis   21401.0  Anne Arundel
# 12984  Purchased  Annapolis   21401.0  Anne Arundel
# 12985  Purchased  Annapolis   21401.0  Anne Arundel
# 12986  Purchased  Annapolis   21401.0  Anne Arundel
# 12987  Purchased  Annapolis   21401.0  Anne Arundel
#
#                                                 Location
# 12983  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12984  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12985  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12986  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12987  Annapolis, Maryland 21401\n(38.98329567400003,...

# %%
df.sample(5)
# Out:
#                                  Program Name       Technology  \
# 12735  Residential Clean Energy Grant Program       Geothermal
# 2249   Residential Clean Energy Grant Program  Solar Hot Water
# 6      Residential Clean Energy Grant Program       Geothermal
# 9468   Residential Clean Energy Grant Program  Solar Hot Water
# 12943       Hist Residential Renewable Grants         Solar PV
#
#       Application Received Date  Award Date Award Amount Actual Start Date  \
# 12735                01/01/2007  01/01/2007     1,000.00               NaN
# 2249                 12/10/2013  12/26/2013       500.00        09/04/2013
# 6                    11/15/2014  12/09/2014     3,000.00        04/01/2013
# 9468                 06/24/2010  10/01/2010     2,000.00        04/29/2010
# 12943                01/01/2006  01/01/2006     3,000.00               NaN
#
#       Actual End Date    Award Status Last Invoice Received Date  \
# 12735      01/01/2007  Award Complete                        NaN
# 2249       10/09/2013  Award Complete                 02/06/2014
# 6          01/27/2014  Award Complete                 01/07/2015
# 9468       04/30/2010  Award Complete                 12/03/2010
# 12943      01/01/2006  Award Complete                        NaN
#
#       Total Disbursed Amount Capacity Capacity Units Total Project Cost  \
# 12735                   0.00     4.92            ton                NaN
# 2249                  500.00       64           sqft           9,450.00
# 6                   3,000.00        8            ton          67,392.00
# 9468                2,000.00       50           sqft          11,900.00
# 12943                   0.00      1.5             kW          15,932.00
#
#        Ownership           City  Zip Code      County  \
# 12735        NaN            NaN       NaN         NaN
# 2249   Purchased      Baltimore   21244.0   Baltimore
# 6      Purchased        Phoenix   21131.0   Baltimore
# 9468   Purchased  Ellicott City   21042.0      Howard
# 12943  Purchased       Bethesda   20814.0  Montgomery
#
#                                                 Location
# 12735  Maryland\n(39.290582950000044, -76.60925984299...
# 2249   Baltimore, Maryland 21244\n(39.33537581400003,...
# 6      Phoenix, Maryland 21131\n(39.508267928000066, ...
# 9468   Ellicott City, Maryland 21042\n(39.27363763100...
# 12943  Bethesda, Maryland 20814\n(38.99252881000007, ...

# %%
#returning the data type of each column
df.dtypes
# Out:
# Program Name                   object
# Technology                     object
# Application Received Date      object
# Award Date                     object
# Award Amount                   object
# Actual Start Date              object
# Actual End Date                object
# Award Status                   object
# Last Invoice Received Date     object
# Total Disbursed Amount         object
# Capacity                       object
# Capacity Units                 object
# Total Project Cost             object
# Ownership                      object
# City                           object
# Zip Code                      float64
# County                         object
# Location                       object
# dtype: object

# %% [markdown]
# ### Data Cleaning

# %%
#counting the null values present in the dataframe
#citation - https://stackoverflow.com/questions/26266362/how-to-count-the-nan-values-in-a-column-in-pandas-dataframe
df.isnull().sum()
# Out:
# Program Name                     0
# Technology                       2
# Application Received Date        3
# Award Date                       0
# Award Amount                     0
# Actual Start Date             1430
# Actual End Date                 58
# Award Status                     0
# Last Invoice Received Date    1326
# Total Disbursed Amount           0
# Capacity                         5
# Capacity Units                   0
# Total Project Cost             119
# Ownership                       95
# City                            95
# Zip Code                        95
# County                          97
# Location                         0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 3325

# %%
#replacing the occurances of commas in columns where commas are present
#citation - https://stackoverflow.com/questions/25698710/replace-all-occurrences-of-a-string-in-a-pandas-dataframe-python
df['Award Amount'] = df['Award Amount'].str.replace(',', '')
df['Total Disbursed Amount'] = df['Total Disbursed Amount'].str.replace(',', '')
df['Capacity'] = df['Capacity'].str.replace(',', '')
df['Total Project Cost'] = df['Total Project Cost'].str.replace(',', '')
df
# Out:
#                                  Program Name          Technology  \
# 12979      01/01/2005  Award Complete                        NaN
# 12980      01/01/2005  Award Complete                        NaN
# 12981      01/01/2005  Award Complete                        NaN
# 12982      01/01/2005  Award Complete                        NaN
# 12983      01/01/2005  Award Complete                        NaN
# 12984      01/01/2005  Award Complete                        NaN
# 12985      01/01/2005  Award Complete                        NaN
# 12986      01/01/2005  Award Complete                        NaN
# 12987      01/01/2005  Award Complete                        NaN
#
#       Total Disbursed Amount            Capacity Capacity Units  \
# 0                    3000.00                 3.5            ton
# 1                    3000.00                   4            ton
# 2                     500.00                64.3           sqft
# 3                    3000.00                   5            ton
# 4                    1000.00                6.48             kW
# 5                    1000.00                8.75             kW
# 6                    3000.00                   8            ton
# 7                    1000.00                6.88             kW
# 8                    3000.00                   3            ton
# 9                    1000.00                2.97             kW
# 10                   1000.00  11.515000000000001             kW
# 11                   1000.00                   8             kW
# 12                   1000.00  8.5749999999999993             kW
# 13                   1000.00                  12             kW
# 14                   1000.00                9.81             kW
# 15                   1000.00                 6.3             kW
# 16                   3000.00                   7            ton
# 17                   1000.00                10.6             kW
# 18                   1000.00                   2             kW
# 19                   3000.00                   6            ton
# 20                    500.00                  54           sqft
# 21                    700.00               52000        BTUs/hr
# 22                    500.00                  48           sqft
# 23                   1000.00                3.85             kW
# 24                    500.00                  48           sqft
# 25                   1000.00                4.95             kW
# 26                    500.00                  48           sqft
# 27                   1000.00                6.12             kW
# 28                   1000.00                   2             kW
# 29                   1000.00  4.8600000000000003             kW
# ...                      ...                 ...            ...
# 12958                   0.00  2.2999999999999998             kW
# 12959                   0.00  2.2999999999999998             kW
# 12960                   0.00                  50           sqft
# 12961                   0.00  2.2999999999999998             kW
# 12962                   0.00                  50           sqft
# 12963                   0.00                  50           sqft
# 12964                   0.00  2.2999999999999998             kW
# 12965                   0.00                  50           sqft
# 12966                   0.00  2.2999999999999998             kW
# 12967                   0.00                  50           sqft
# 12968                   0.00  2.2999999999999998             kW
# 12969                   0.00                  50           sqft
# 12970                   0.00  2.2999999999999998             kW
# 12971                   0.00                  50           sqft
# 12972                   0.00                  50           sqft
# 12973                   0.00                  50           sqft
# 12974                   0.00                  50           sqft
# 12975                   0.00                  50           sqft
# 12976                   0.00  2.2999999999999998             kW
# 12977                   0.00                  50           sqft
# 12978                   0.00  2.2999999999999998             kW
# 12979                   0.00  2.2999999999999998             kW
# 12980                   0.00                  50           sqft
# 12981                   0.00                  50           sqft
# 12982                   0.00  2.2999999999999998             kW
# 12983                   0.00                  50           sqft
# 12984                   0.00                  50           sqft
# 12985                   0.00                  50           sqft
# 12986                   0.00                  50           sqft
# 12987                   0.00                  50           sqft
#
#       Total Project Cost  Ownership             City  Zip Code  \
# 0               17909.00  Purchased       North East   21901.0
# 1               41560.00  Purchased      Lutherville   21093.0
# 2               50000.00  Purchased      Forest Hill   21050.0
# 3               27829.00  Purchased           Laurel   20723.0
# 4               22750.00  Purchased     Gaithersburg   20878.0
# 5               27000.00  Purchased         La Plata   20646.0
# 6               67392.00  Purchased          Phoenix   21131.0
# 7               20003.34  Purchased    Ellicott City   21043.0
# 5              Charles  La Plata, Maryland 20646\n(38.52460647800007, ...
# 6            Baltimore  Phoenix, Maryland 21131\n(39.508267928000066, ...
# 7               Howard  Ellicott City, Maryland 21043\n(39.25955981300...
# 8         Anne Arundel  Severn, Maryland 21144\n(39.12625939000003, -7...
# 9      Prince George's  College Park, Maryland 20740\n(38.996717396000...
# 10        Anne Arundel  Millersville, Maryland 21108\n(39.100428332000...
# 11              Howard  Clarksville, Maryland 21029\n(39.2025794110000...
# 12        Anne Arundel  Glen Burnie, Maryland 21061\n(39.1570394090000...
# 13              Howard  Fulton, Maryland 20759\n(39.15038720500007, -7...
# 14     Prince George's  Laurel, Maryland 20707\n(39.09811678900007, -7...
# 15              Howard  Laurel, Maryland 20723\n(39.127289156000074, -...
# 16          Montgomery  Barnesville, Maryland 20838\n(39.2234875780000...
# 17           Baltimore  Timonium, Maryland 21093\n(39.44221950000008, ...
# 18           Frederick  Ijamsville, Maryland 21754\n(39.33386809800004...
# 19        Anne Arundel  Gambrills, Maryland 21054\n(39.03853807400003,...
# 20             Harford  Forest Hill, Maryland 21050\n(39.5734864610000...
# 21             Harford  Bel Air, Maryland 21015\n(39.53091844200003, -...
# 22           Frederick  Ijamsville, Maryland 21754\n(39.33386809800004...
# 23           Baltimore  Reisterstown, Maryland 21136\n(39.461828509000...
# 24           Baltimore  Edgemere, Maryland 21219\n(39.232329664000076,...
# 25                Kent  Chestertown, Maryland 21620\n(39.2157665030000...
# 26     Prince George's  Upper Marlboro, Maryland 20774\n(38.8855591200...
# 27             Charles  Waldorf, Maryland 20602\n(38.59849764200004, -...
# 28     Prince George's  Clinton, Maryland 20735\n(38.75721634800004, -...
# 29        Anne Arundel  Tracy's Landing, Maryland 20779\n(38.763777306...
# ...                ...                                                ...
# 12958     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12959     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12960     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12961     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12962     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12963     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12964     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12965     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12966     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12967     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12968     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12969     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12970     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12971     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12972     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12973     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12974     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12975     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12976     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12977     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12978     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12979     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12980     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12981     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12982     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12983     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12984     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12985     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12986     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
# 12987     Anne Arundel  Annapolis, Maryland 21401\n(38.98329567400003,...
#
# [12988 rows x 18 columns]

# %%
#converting the data type of columns to float and dates into date data type in the dataframe
#citation - https://stackoverflow.com/questions/16852911/how-do-i-convert-dates-in-a-pandas-data-frame-to-a-date-data-type
df['Award Amount'] = df['Award Amount'].astype(float)
df['Total Disbursed Amount'] = df['Total Disbursed Amount'].astype(float)
df['Capacity'] = df['Capacity'].astype(float)
df['Application Received Date'] = df['Application Received Date'].astype('datetime64[ns]')
df['Award Date'] = df['Award Date'].astype('datetime64[ns]')
df['Actual Start Date'] = df['Actual Start Date'].astype('datetime64[ns]')
df['Actual End Date'] = df['Actual End Date'].astype('datetime64[ns]')
df['Total Project Cost'] = df['Total Project Cost'].astype(float)
df['Last Invoice Received Date'] = df['Last Invoice Received Date'].astype('datetime64[ns]')
df.dtypes
# Out:
# Program Name                          object
# Technology                            object
# Application Received Date     datetime64[ns]
# Award Date                    datetime64[ns]
# Award Amount                         float64
# Actual Start Date             datetime64[ns]
# Actual End Date               datetime64[ns]
# Award Status                          object
# Last Invoice Received Date    datetime64[ns]
# Total Disbursed Amount               float64
# Capacity                             float64
# Capacity Units                        object
# Total Project Cost                   float64
# Ownership                             object
# City                                  object
# Zip Code                             float64
# County                                object
# Location                              object
# dtype: object

# %%
#filling the missing values
#citation - https://www.geeksforgeeks.org/python-pandas-dataframe-fillna-to-replace-null-values-in-dataframe/
df['Technology'].fillna( method ='ffill', inplace = True)
df['Application Received Date'].fillna( method ='ffill', inplace = True)
df['Actual Start Date'].fillna( method ='ffill', inplace = True)
df['Actual End Date'].fillna( method ='ffill', inplace = True)
df['Last Invoice Received Date'].fillna( method ='ffill', inplace = True)
df['Capacity'].fillna( method ='ffill', inplace = True) 
df['Total Project Cost'].fillna( method ='ffill', inplace = True)
df['Ownership'].fillna( method ='ffill', inplace = True)
df['City'].fillna( method ='ffill', inplace = True)
df['Zip Code'].fillna( method ='ffill', inplace = True)
df['County'].fillna( method ='ffill', inplace = True)

# %%
df.isnull().sum()
# Out:
# Program Name                  0
# Technology                    0
# Application Received Date     0
# Award Date                    0
# Award Amount                  0
# Actual Start Date             0
# Actual End Date               0
# Award Status                  0
# Last Invoice Received Date    0
# Total Disbursed Amount        0
# Capacity                      0
# Capacity Units                0
# Total Project Cost            0
# Ownership                     0
# City                          0
# Zip Code                      0
# County                        0
# Location                      0
# dtype: int64

# %%
#converting the data type of column from float to int
#citation - https://stackoverflow.com/questions/21291259/convert-floats-to-ints-in-pandas
df['Zip Code'] = df['Zip Code'].apply(np.int64)

# %%
#creating a new column for year to try to analyze better and get a better visualization
#citation - https://stackoverflow.com/questions/30405413/python-pandas-extract-year-from-datetime-dfyear-dfdate-year-is-not
df['Year'] = df['Award Date'].dt.year

# %%
#checking if any columns have 0 values in them
#citation - https://stackoverflow.com/questions/48570797/check-if-pandas-column-contains-other-values-other-than-zero
(df != 0).all()
# Out:
# Program Name                   True
# Technology                     True
# Application Received Date      True
# Award Date                     True
# Award Amount                  False
# Actual Start Date              True
# Actual End Date                True
# Award Status                   True
# Last Invoice Received Date     True
# Total Disbursed Amount        False
# Capacity                      False
# Capacity Units                 True
# Total Project Cost             True
# Ownership                      True
# City                           True
# Zip Code                       True
# County                         True
# Location                       True
# Year                           True
# dtype: bool

# %%
#replacing all the 0 values present in the columns to its respective mean values
#citation - https://stackoverflow.com/questions/37506488/python-pandas-dataframe-replace-0-with-median-value
a = df['Total Disbursed Amount'].mean(skipna=True)
b = df['Award Amount'].mean(skipna=True)
c = df['Capacity'].mean(skipna=True)

# %%
#citation - https://stackoverflow.com/questions/37506488/python-pandas-dataframe-replace-0-with-median-value
df['Total Disbursed Amount'] = df['Total Disbursed Amount'].replace(0,a) 
df['Award Amount'] = df['Award Amount'].replace(0,b)
df['Capacity'] = df['Capacity'].replace(0,c)

# %%
#generating the statistics of the columns Award Amount, Disbursed amount, Capacity, Total Project Cost in my dataset
#citation - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html
df.describe()
# Out:
#         Award Amount  Total Disbursed Amount      Capacity  \
# count   12988.000000            12988.000000  12988.000000
# mean     2597.912877             2456.409061   3606.905710
# std      3754.009861             3508.167731  12781.542138
# min        25.850000               25.850000      0.108000
# 25%      1000.000000             1000.000000      4.000000
# 50%      1759.500000             2000.000000      6.000000
# 75%      3000.000000             3000.000000     17.500000
# max    110000.000000            75000.000000  83220.000000
#
#        Total Project Cost      Zip Code          Year
# count        1.298800e+04  12988.000000  12988.000000
# mean         3.205710e+04  21151.606714   2011.514398
# std          4.582865e+04    366.103773      1.894506
# min          5.345400e+02  20145.000000   2005.000000
# 25%          1.302900e+04  20872.000000   2010.000000
# 50%          2.626800e+04  21074.000000   2012.000000
# 75%          3.793685e+04  21401.000000   2013.000000
# max          2.000000e+06  22172.000000   2014.000000

# %%
(df != 0).all()
# Out:
# Program Name                  True
# Technology                    True
# Application Received Date     True
# Award Date                    True
# Award Amount                  True
# Actual Start Date             True
# Actual End Date               True
# Award Status                  True
# Last Invoice Received Date    True
# Total Disbursed Amount        True
# Capacity                      True
# Capacity Units                True
# Total Project Cost            True
# Ownership                     True
# City                          True
# Zip Code                      True
# County                        True
# Location                      True
# Year                          True
# dtype: bool

# %% [markdown]
# ### Data Visualization

# %%
#plotting a histogram for analyzing the average of total project cost
#citation - https://medium.com/python-pandemonium/data-visualization-in-python-histogram-in-matplotlib-dce38f49f89c
df['Total Project Cost'].hist(bins = 100, figsize = (10,10), color = "grey")
plt.xlabel('Project Cost')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#plotting a histogram for analysing the awards granted in each year
#citation - https://medium.com/python-pandemonium/data-visualization-in-python-histogram-in-matplotlib-dce38f49f89c
df['Year'].hist(figsize = (10,10), color = "pink")
plt.xlabel('Awarded Year')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# 1. Which renewable energy project has been implemented more over the years? - **Solar Energy project has been implemented the most as per the below graph.**

# %%
maindf = df
unique_topic = df['Technology'].unique()
df1 = df.groupby(['Technology'])['Year'].agg("sum")  #citation - https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/
dict_values = {}
for topic in unique_topic:
    dict_values[str(topic)] = df1.get(key=topic) #citation - https://www.geeksforgeeks.org/python-pandas-dataframe-get/
#keys = list(dict_values.keys())

# %%
#creating a new dataframe by converting the dictionary values into a list
#citation - https://www.pythoncentral.io/convert-dictionary-values-list-python/
df2 = pd.DataFrame(list(dict_values.items()), columns=['Technology', 'Year'])

# %%
#creating pie chart to show which energy project has been implemented the most out of all the projects
#citation - https://towardsdatascience.com/data-visualization-using-matplotlib-16f1aae5ce70
plt.figure(figsize=(20,8))
ax1 = plt.subplot(121, aspect='equal')
df2.plot(kind='pie', y = 'Year', ax=ax1, autopct='%1.1f%%', 
 startangle=90, shadow=False, labels=df2['Technology'], legend = False, fontsize=14)

# %% [markdown]
# 2. Whether the Award Amount increases or decreases every year? - **After examining the graph, we can see that the Award Amount is decreasing after 2012 so the hypothesis for the Award Amount increasing yearly is false.**

# %%
plt.figure(figsize=(10,10))
plt.bar(df['Year'], df['Award Amount'])
plt.title('Award Amount Details')
plt.xlabel('Year')
plt.ylabel('Award Amount')
plt.show()

# %% [markdown]
# 3. Is there a particular areas that have more projects (# of project, and/or total spending)? - **As per the below graph, Montgomery county has got more projects than any other areas and Garrett county has the least projects.**

# %%
df['County'].value_counts().plot(kind='bar', color = "green")
